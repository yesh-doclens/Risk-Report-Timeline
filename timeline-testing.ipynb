# %% [markdown]
# ### Initial Testing

# %%
results = [
    {
        "id": 1123,
        "uuid": "0937fc23-7097-405e-b643-69c4cb760434",
        "claim_file": 743,
        "created_at": "2026-03-18T13:12:35.999552+05:30",
        "updated_at": "2026-03-18T15:08:44.455809+05:30",
        "metadata": {},
        "name": "Brooks and Crooks.pdf",
        "state": "annotated",
        "risk_info": {
            "document_risk_score": "H"
        },
        "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/0937fc23-7097-405e-b643-69c4cb760434__document_uuid__Brooks%20and%20Crooks.pdf?Expires=1775462975&Signature=YvNu8iaumUiAlq8GwpvLjDsMlb1iJID7nONkez22Is3iAxBGwuuE0jZXN2PlwVJKNghHeHUIARk3zSKcB9tdyjkLW02qzJcU7RE228R37JD0nzPdnyt~hDxi93hkFIdMlOU6~vPOEhzCEOJe7212MK~LAn7xZoJWiAifeYJ2IdxCNB5kN5Upqq03q3jgTOGzycQujtoSNbeUJW7DNwAe7fBu9iTxCoo7XAuX2ooZ4GS4-s-QWkz17wHlt6PJzc~Z1by058yYcM1uBy4TH6HEausbfDEnMGLLAXbiAryztNNrbLZPUYblAyRlwHGMcdXmLnopFJvJEqLI63XVhMjUUw__&Key-Pair-Id=K382VBQQV0CLSN",
        "document_type": "Demand Package",
        "raw_content_type": "application/pdf",
        "annotations": {
            "claim-characteristics": {
                "annotations": [
                    {
                        "type": "H",
                        "uuid": "48a42dfe-fb96-4330-8ecb-081fd0aee0c5",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "from the impact with the interior of the vehicle. Mrs. Collins was airlifted from the scene of the",
                                "context": [
                                    "Mrs. Collins was airlifted from the scene of the accident to Buffalo Medical Center."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11742391437292099,
                                            "Y": 0.7042007446289062
                                        },
                                        {
                                            "X": 0.8606888055801392,
                                            "Y": 0.7042168974876404
                                        },
                                        {
                                            "X": 0.8606889247894287,
                                            "Y": 0.7183980345726013
                                        },
                                        {
                                            "X": 0.11742419749498367,
                                            "Y": 0.7183818817138672
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.7042007446289062,
                                        "Left": 0.11742391437292099,
                                        "Width": 0.7432650327682495,
                                        "Height": 0.01419731043279171
                                    }
                                },
                                "context_tokens": {
                                    "next": "accident to Buffalo Medical Center. She was examined in the emergency room by Dr. William\nThomas who confirmed her injuries",
                                    "prev": "assert that this is a case of distracted driving that supports a\npunitive damage claim.\nMary Collins sustained significant injuries in the accident. She had bruises on her upper body\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Airlifted",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "H",
                        "uuid": "7a7d0e31-4e10-46d4-a431-1ae24f5b12ad",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "has now diagnosed her with a moderate permanent brain injury resulting from the accident. In",
                                "context": [
                                    "Dr. .Coleman has continued to monitor and treat Mrs. Collins has now diagnosed her with a moderate permanent brain injury resulting from the accident."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11804667115211487,
                                            "Y": 0.7960556745529175
                                        },
                                        {
                                            "X": 0.8649463653564453,
                                            "Y": 0.7960719466209412
                                        },
                                        {
                                            "X": 0.8649464845657349,
                                            "Y": 0.8103387951850891
                                        },
                                        {
                                            "X": 0.11804694682359695,
                                            "Y": 0.8103225231170654
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.7960556745529175,
                                        "Left": 0.11804667115211487,
                                        "Width": 0.7468998432159424,
                                        "Height": 0.014283113181591034
                                    }
                                },
                                "context_tokens": {
                                    "next": "addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain.\nMr. Collins has had pain in her",
                                    "prev": "not improve and 10 days later she was examined at the Buffalo Neuroscience Center by Dr.\nKatherine Coleman, a neurologist. Dr. .Coleman has continued to monitor and treat Mrs. Collins\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Brain Injury",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "H",
                        "uuid": "3ea0b3d4-7f82-4c5d-91f5-0ecbca4e9bc8",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "Continued monitoring, treatment and therapy for permanent brain injury $1,000,000",
                                "context": [
                                    "Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment and therapy for permanent brain injury $1,000,000 Surgery for lower back to relieve pain and subsequent physical therapy $200,000 In addition, Mrs. Collins has been unable to return to her job as a human resources manager."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.1769712120294571,
                                            "Y": 0.423703670501709
                                        },
                                        {
                                            "X": 0.8371518850326538,
                                            "Y": 0.42370709776878357
                                        },
                                        {
                                            "X": 0.8371516466140747,
                                            "Y": 0.4378868341445923
                                        },
                                        {
                                            "X": 0.1769709587097168,
                                            "Y": 0.43788325786590576
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.423703670501709,
                                        "Left": 0.1769709587097168,
                                        "Width": 0.660180926322937,
                                        "Height": 0.014183160848915577
                                    }
                                },
                                "context_tokens": {
                                    "next": "Surgery for lower back to relieve pain and subsequent physical therapy $200,000\nIn addition, Mrs. Collins has been unable to",
                                    "prev": "related\nto injuries is $1,200,000.\nPast Medical Expenses\nBuffalo Medical Center $30,000\nNeuroscience Center of Buffalo $35,000\nEmergency Airlift and Miscellaneous prescription and medical devices $15,000\nFuture Estimated Medical Expenses\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Brain Injury",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "M",
                        "uuid": "cdafa867-93d9-4e68-8a7a-0793d181a61a",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "loss of society and consortium.",
                                "context": [
                                    "Thus, Mr. Collins is entitled to compensation for his loss of society and consortium."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11807016283273697,
                                            "Y": 0.1851763278245926
                                        },
                                        {
                                            "X": 0.3624056875705719,
                                            "Y": 0.18517667055130005
                                        },
                                        {
                                            "X": 0.3624054491519928,
                                            "Y": 0.19910624623298645
                                        },
                                        {
                                            "X": 0.11806991696357727,
                                            "Y": 0.1991058588027954
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.1851763278245926,
                                        "Left": 0.11806991696357727,
                                        "Width": 0.24433577060699463,
                                        "Height": 0.013929924927651882
                                    }
                                },
                                "context_tokens": {
                                    "next": "Economic Damages\nMary Collins has incurred $80,000 in medical expenses to date. The cost for future care related\nto injuries",
                                    "prev": "same level of activity. These changes are likely to be permanent and will impact\ntheir relationship for many years to come. Thus, Mr. Collins is entitled to compensation for his\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Loss of Society",
                        "RiskCategory": "M",
                        "AnnotationType": "positive",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "M",
                        "uuid": "a439d484-5c4c-4ff1-80a7-ae17ad2144fe",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain.",
                                "context": [
                                    "In addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain."
                                ],
                                "is_true": "neutral",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.1177283227443695,
                                            "Y": 0.8144634366035461
                                        },
                                        {
                                            "X": 0.8564535975456238,
                                            "Y": 0.8144795298576355
                                        },
                                        {
                                            "X": 0.8564537763595581,
                                            "Y": 0.8284070491790771
                                        },
                                        {
                                            "X": 0.11772859841585159,
                                            "Y": 0.8283909559249878
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.8144634366035461,
                                        "Left": 0.1177283227443695,
                                        "Width": 0.7387254238128662,
                                        "Height": 0.013943624682724476
                                    }
                                },
                                "context_tokens": {
                                    "next": "Mr. Collins has had pain in her back and suffered from persistent headaches since the day of\nthe accident. Mrs.",
                                    "prev": "Dr.\nKatherine Coleman, a neurologist. Dr. .Coleman has continued to monitor and treat Mrs. Collins\nhas now diagnosed her with a moderate permanent brain injury resulting from the accident. In\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Surgery",
                        "RiskCategory": "M",
                        "AnnotationType": "neutral",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "M",
                        "uuid": "4a377c20-c26a-433f-8836-25e02f4b9677",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "Surgery for lower back to relieve pain and subsequent physical therapy $200,000",
                                "context": [
                                    "Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment and therapy for permanent brain injury $1,000,000 Surgery for lower back to relieve pain and subsequent physical therapy $200,000 In addition, Mrs. Collins has been unable to return to her job as a human resources manager."
                                ],
                                "is_true": "neutral",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.17693603038787842,
                                            "Y": 0.44220876693725586
                                        },
                                        {
                                            "X": 0.820236086845398,
                                            "Y": 0.4422122836112976
                                        },
                                        {
                                            "X": 0.8202358484268188,
                                            "Y": 0.4564583897590637
                                        },
                                        {
                                            "X": 0.17693577706813812,
                                            "Y": 0.45645472407341003
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.44220876693725586,
                                        "Left": 0.17693577706813812,
                                        "Width": 0.6433003544807434,
                                        "Height": 0.014249606989324093
                                    }
                                },
                                "context_tokens": {
                                    "next": "In addition, Mrs. Collins has been unable to return to her job as a human resources manager.\nHer compensation before",
                                    "prev": "Center $30,000\nNeuroscience Center of Buffalo $35,000\nEmergency Airlift and Miscellaneous prescription and medical devices $15,000\nFuture Estimated Medical Expenses\nContinued monitoring, treatment and therapy for permanent brain injury $1,000,000\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Surgery",
                        "RiskCategory": "M",
                        "AnnotationType": "neutral",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "H",
                        "uuid": "9bc33b01-d767-4a15-abc0-78133510842f",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "will be amending our Complaint to assert that this is a case of distracted driving that supports a",
                                "context": [
                                    "Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a punitive damage claim."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11711711436510086,
                                            "Y": 0.6307869553565979
                                        },
                                        {
                                            "X": 0.8703730702400208,
                                            "Y": 0.6308033466339111
                                        },
                                        {
                                            "X": 0.8703731894493103,
                                            "Y": 0.6449556946754456
                                        },
                                        {
                                            "X": 0.11711739003658295,
                                            "Y": 0.6449393033981323
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.6307869553565979,
                                        "Left": 0.11711711436510086,
                                        "Width": 0.75325608253479,
                                        "Height": 0.014168708585202694
                                    }
                                },
                                "context_tokens": {
                                    "next": "punitive damage claim.\nMary Collins sustained significant injuries in the accident. She had bruises on her upper body\nfrom the",
                                    "prev": "clearly had time to adjust his speed to allow a safe merger\nbut failed to give Mrs. Collins sufficient room to merge. Clearly your insured was at fault and we\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Distracted driving",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Liability"
                    },
                    {
                        "type": "H",
                        "uuid": "83f7d1e6-806a-4e2a-a379-b2e9b032618f",
                        "Answer": [
                            {
                                "page": 3,
                                "score": 1.0,
                                "answer": "Affidavit confirming that there is no other potentially available insurance coverage and that",
                                "context": [
                                    "We also require an Affidavit confirming that there is no other potentially available insurance coverage and that Peterson Trucking and Jimmy Peterson do not have liquid assets in excess of $3,000,000."
                                ],
                                "is_true": "neutral",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11735175549983978,
                                            "Y": 0.18494896590709686
                                        },
                                        {
                                            "X": 0.8323141932487488,
                                            "Y": 0.184942364692688
                                        },
                                        {
                                            "X": 0.832314133644104,
                                            "Y": 0.19925768673419952
                                        },
                                        {
                                            "X": 0.11735181510448456,
                                            "Y": 0.19926412403583527
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.184942364692688,
                                        "Left": 0.11735175549983978,
                                        "Width": 0.7149624824523926,
                                        "Height": 0.014321764931082726
                                    }
                                },
                                "context_tokens": {
                                    "next": "Peterson Trucking and Jimmy Peterson do not have liquid assets in excess of $3,000,000.\nPayment should be made by check",
                                    "prev": "this final offer to resolve their claims for the full $3,000,000 policy\nlimits provided payment is made within 28 days from the date of this letter. We also require an\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Affidavit",
                        "RiskCategory": "H",
                        "AnnotationType": "neutral",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "H",
                        "uuid": "1a9e64e4-72df-4adb-b061-716b5dc15647",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients",
                                "context": [
                                    "This failure to respond is a clear indication of bad faith claim handling."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11784635484218597,
                                            "Y": 0.8460082411766052
                                        },
                                        {
                                            "X": 0.845192015171051,
                                            "Y": 0.8460168838500977
                                        },
                                        {
                                            "X": 0.8451917767524719,
                                            "Y": 0.8603160977363586
                                        },
                                        {
                                            "X": 0.11784610152244568,
                                            "Y": 0.8603072762489319
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.8460082411766052,
                                        "Left": 0.11784610152244568,
                                        "Width": 0.7273459434509277,
                                        "Height": 0.014307867735624313
                                    }
                                },
                                "context_tokens": {
                                    "next": "would prefer to get his case resolved without further delay and, therefore they make the\nfollowing offer but if the",
                                    "prev": "in this\nletter is void if this understanding is not correct.\nAs you know, our clients made a prior offer to settle and received no response from you or your\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Bad faith",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "H",
                        "uuid": "250a81cb-3d51-4774-b448-945411a5cd24",
                        "Answer": [
                            {
                                "page": 3,
                                "score": 1.0,
                                "answer": "potential bad faith claims against Best Value Insurance.",
                                "context": [
                                    "Our clients would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including potential bad faith claims against Best Value Insurance."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11802652478218079,
                                            "Y": 0.1117396280169487
                                        },
                                        {
                                            "X": 0.5562819242477417,
                                            "Y": 0.11173504590988159
                                        },
                                        {
                                            "X": 0.5562819242477417,
                                            "Y": 0.12584906816482544
                                        },
                                        {
                                            "X": 0.11802658438682556,
                                            "Y": 0.1258535385131836
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.11173504590988159,
                                        "Left": 0.11802652478218079,
                                        "Width": 0.4382553994655609,
                                        "Height": 0.014118500985205173
                                    }
                                },
                                "context_tokens": {
                                    "next": "Mrs and Mr. Collins make this final offer to resolve their claims for the full $3,000,000 policy\nlimits provided payment",
                                    "prev": "prefer to get his case resolved without further delay and, therefore they make the\nfollowing offer but if the claim is not resolved, our clients will pursue all options, including\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Bad faith",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "H",
                        "uuid": "7be03d6e-30ae-47b3-8a68-e9924b202799",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "As you know, our clients made a prior offer to settle and received no response from you or your",
                                "context": [
                                    "As you know, our clients made a prior offer to settle and received no response from you or your insureds."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11734768748283386,
                                            "Y": 0.8277184963226318
                                        },
                                        {
                                            "X": 0.8725867867469788,
                                            "Y": 0.8277272582054138
                                        },
                                        {
                                            "X": 0.8725865483283997,
                                            "Y": 0.8418982625007629
                                        },
                                        {
                                            "X": 0.11734743416309357,
                                            "Y": 0.8418893218040466
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.8277184963226318,
                                        "Left": 0.11734743416309357,
                                        "Width": 0.7552393674850464,
                                        "Height": 0.014179767109453678
                                    }
                                },
                                "context_tokens": {
                                    "next": "insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients\nwould prefer to get",
                                    "prev": "Please advise us immediately if our\nunderstanding of policy limits and available coverage is not correct. The settlement offer in this\nletter is void if this understanding is not correct.\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Offer to Settle",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "H",
                        "uuid": "90c16043-7db1-43e1-8b93-311b5e48d9c6",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "understanding of policy limits and available coverage is not correct. The settlement offer in this",
                                "context": [
                                    "The settlement offer in this letter is void if this understanding is not correct."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11811111867427826,
                                            "Y": 0.772696316242218
                                        },
                                        {
                                            "X": 0.8669068217277527,
                                            "Y": 0.7727043628692627
                                        },
                                        {
                                            "X": 0.8669065833091736,
                                            "Y": 0.7872392535209656
                                        },
                                        {
                                            "X": 0.11811086535453796,
                                            "Y": 0.7872310876846313
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.772696316242218,
                                        "Left": 0.11811086535453796,
                                        "Width": 0.7487959265708923,
                                        "Height": 0.014542931690812111
                                    }
                                },
                                "context_tokens": {
                                    "next": "letter is void if this understanding is not correct.\nAs you know, our clients made a prior offer to settle",
                                    "prev": "forever.\nBased upon the prior communication from you we understand that the applicable policy limits\nare $3,000,000 and that there is no excess coverage. Please advise us immediately if our\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Settlement Offer",
                        "RiskCategory": "H",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "M",
                        "uuid": "013fdf2d-8e73-4dd3-9432-7415a90cd4d8",
                        "Answer": [
                            {
                                "page": 3,
                                "score": 1.0,
                                "answer": "your insured. Any counter-offer will be considered a rejection of this offer and this offer will no",
                                "context": [
                                    "Any counter-offer will be considered a rejection of this offer and this offer will no longer be available."
                                ],
                                "is_true": "negative",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11728315055370331,
                                            "Y": 0.38717252016067505
                                        },
                                        {
                                            "X": 0.861054539680481,
                                            "Y": 0.38716813921928406
                                        },
                                        {
                                            "X": 0.8610544800758362,
                                            "Y": 0.4012812376022339
                                        },
                                        {
                                            "X": 0.11728320270776749,
                                            "Y": 0.40128543972969055
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.38716813921928406,
                                        "Left": 0.11728315055370331,
                                        "Width": 0.7437713742256165,
                                        "Height": 0.014117305167019367
                                    }
                                },
                                "context_tokens": {
                                    "next": "longer be available. Please give this offer careful consideration as it is the last opportunity to\nsettle within policy limits.",
                                    "prev": "complaint seeking punitive damages and exposing your insured to excess or\nuncovered liability.\nPlease forward this letter to your insureds. We look forward to a prompt response from you or\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Counter offer",
                        "RiskCategory": "L",
                        "AnnotationType": "negative",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "M",
                        "uuid": "d222ec1f-6409-47bc-ba0f-77ce4f22ad75",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "punitive damage claim.",
                                "context": [
                                    "Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a punitive damage claim."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11815688759088516,
                                            "Y": 0.649410605430603
                                        },
                                        {
                                            "X": 0.30046385526657104,
                                            "Y": 0.649414598941803
                                        },
                                        {
                                            "X": 0.30046409368515015,
                                            "Y": 0.6634012460708618
                                        },
                                        {
                                            "X": 0.11815716326236725,
                                            "Y": 0.6633973121643066
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.649410605430603,
                                        "Left": 0.11815688759088516,
                                        "Width": 0.1823071986436844,
                                        "Height": 0.013990637846291065
                                    }
                                },
                                "context_tokens": {
                                    "next": "Mary Collins sustained significant injuries in the accident. She had bruises on her upper body\nfrom the impact with the",
                                    "prev": "sufficient room to merge. Clearly your insured was at fault and we\nwill be amending our Complaint to assert that this is a case of distracted driving that supports a\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "punitive",
                        "RiskCategory": "M",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    },
                    {
                        "type": "M",
                        "uuid": "8a913504-20fd-4ac0-b846-f27ed01e5fad",
                        "Answer": [
                            {
                                "page": 3,
                                "score": 1.0,
                                "answer": "in an amended complaint seeking punitive damages and exposing your insured to excess or",
                                "context": [
                                    "Failure to accept this offer will result in an amended complaint seeking punitive damages and exposing your insured to excess or uncovered liability."
                                ],
                                "is_true": "positive",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.11800380796194077,
                                            "Y": 0.3136642873287201
                                        },
                                        {
                                            "X": 0.8487472534179688,
                                            "Y": 0.31365910172462463
                                        },
                                        {
                                            "X": 0.848747193813324,
                                            "Y": 0.3276281952857971
                                        },
                                        {
                                            "X": 0.11800386011600494,
                                            "Y": 0.32763323187828064
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.31365910172462463,
                                        "Left": 0.11800380796194077,
                                        "Width": 0.7307434678077698,
                                        "Height": 0.013974128291010857
                                    }
                                },
                                "context_tokens": {
                                    "next": "uncovered liability.\nPlease forward this letter to your insureds. We look forward to a prompt response from you or\nyour",
                                    "prev": "any liens. If your insured requires a release, Mrs and Mr. Collins will\nexecute a standard claim release upon receipt of the funds. Failure to accept this offer will result\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "punitive",
                        "RiskCategory": "M",
                        "AnnotationType": "positive",
                        "Characteristic": "Other"
                    }
                ]
            }
        }
    },
    {
        "id": 1124,
        "uuid": "04d0960e-f3c5-449d-9c7f-ad1eb1c7452f",
        "claim_file": 743,
        "created_at": "2026-03-18T14:07:49.225556+05:30",
        "updated_at": "2026-03-18T15:05:54.909840+05:30",
        "metadata": {},
        "name": "Medical Examination Report.pdf",
        "state": "annotated",
        "risk_info": {
            "document_risk_score": "H"
        },
        "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/04d0960e-f3c5-449d-9c7f-ad1eb1c7452f__document_uuid__Medical%20Examination%20Report.pdf?Expires=1775462975&Signature=apKiyKYsw6zcH2i1cPgcQJPIzMi1BjBR~Rb2~ZLrWZ8OrzNHpCAZrtpQTpH2fhmKtv6li~QAC93hZsZviZH1w6CrU4-784r4GnYCUt9Khr5DzpxA2HhB2A8ZYAyQyfefcpp7wIfwRQfyhEttmKEgy~84r4v4Mswp18nzqR01iqboBiew0jAMvcB1h91YNIJzPHPfHHHA0mWOC5DmhM0ruH8VcC0eWBf2D4wo796uE4RqMZl7MKNwsLpmjGMPOudGottsk72qgLIzEl8CLZsZLZNMwjaAJ3GVJCO7AWIsOdg7cD2nhIQU~1dPXjY4dsfXJCd2O~Q8ZWX4nowDkMrjXA__&Key-Pair-Id=K382VBQQV0CLSN",
        "document_type": "Medical Report Form",
        "raw_content_type": "application/pdf",
        "annotations": {
            "claim-characteristics": {
                "annotations": [
                    {
                        "type": "H",
                        "uuid": "05c73616-97af-4218-be3c-004d12379cd8",
                        "Answer": [
                            {
                                "page": 1,
                                "score": 1.0,
                                "answer": "PastMedical Conditions: Diabetes, Hypertension, Cancer, lumbar fusion.",
                                "context": [
                                    "Part 2: Medical History Checklist PastMedical Conditions: Diabetes, Hypertension, Cancer, lumbar fusion."
                                ],
                                "is_true": "neutral",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.13895167410373688,
                                            "Y": 0.3135140538215637
                                        },
                                        {
                                            "X": 0.7112232446670532,
                                            "Y": 0.3135175406932831
                                        },
                                        {
                                            "X": 0.7112234234809875,
                                            "Y": 0.32748228311538696
                                        },
                                        {
                                            "X": 0.1389520764350891,
                                            "Y": 0.3274786174297333
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.3135140538215637,
                                        "Left": 0.13895167410373688,
                                        "Width": 0.5722717642784119,
                                        "Height": 0.013968243263661861
                                    }
                                },
                                "context_tokens": {
                                    "next": "Current Medications: Metoprolol, Insulin\nAllergies: None\nFamily History of Illness: Mother living, father died at age 60 from lung cancer.",
                                    "prev": "02/03/1989\nGender: Female\nContact Number: 440-285-9876\nAddress: 8753 Park Ave, Cleveland, Ohio 39876\nReason for Examination: Driver in auto accident transported from scene via helicopter.\nPart 2: Medical History Checklist\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Fusion",
                        "RiskCategory": "H",
                        "AnnotationType": "neutral",
                        "Characteristic": "Damage"
                    },
                    {
                        "type": "M",
                        "uuid": "c0ad5833-62b6-42af-ba2e-82a6b3fa1141",
                        "Answer": [
                            {
                                "page": 2,
                                "score": 1.0,
                                "answer": "Recommendations: Rest, Tylenol for pain. See neuropsychologist and/or neurologist if",
                                "context": [
                                    "See neuropsychologist and/or neurologist if headaches continue more than 7 days."
                                ],
                                "is_true": "neutral",
                                "geometry": {
                                    "Polygon": [
                                        {
                                            "X": 0.13882970809936523,
                                            "Y": 0.4351511597633362
                                        },
                                        {
                                            "X": 0.8269491195678711,
                                            "Y": 0.4351572096347809
                                        },
                                        {
                                            "X": 0.8269490003585815,
                                            "Y": 0.4489651024341583
                                        },
                                        {
                                            "X": 0.13882966339588165,
                                            "Y": 0.44895896315574646
                                        }
                                    ],
                                    "BoundingBox": {
                                        "Top": 0.4351511597633362,
                                        "Left": 0.13882966339588165,
                                        "Width": 0.6881194710731506,
                                        "Height": 0.013813936151564121
                                    }
                                },
                                "context_tokens": {
                                    "next": "headaches continue more than 7 days.\nFit for Duty: Not at this time if symptoms dissipate can return to work",
                                    "prev": "cerebellar atrophy appears to be\nchronic.\nPart 6: Physician's Evaluation and Recommendations\nFindings: Soft tissue injuries likely caused by vehicle accident. Further neuro assessment\nmay be warranted if headaches persist.\n",
                                    "next_count": 20,
                                    "prev_count": 30
                                },
                                "selection_status": ""
                            }
                        ],
                        "Question": "Neuropsychologist",
                        "RiskCategory": "M",
                        "AnnotationType": "neutral",
                        "Characteristic": "Damage"
                    }
                ]
            }
        }
    }
]

# %%
import random
from datetime import datetime, timedelta

def random_date(start, end):
    delta = end - start
    random_days = random.randint(0, delta.days)
    return start + timedelta(days=random_days)

def add_dates_to_annotations(results):
    start_date = datetime(2026, 1, 1)
    end_date = datetime(2026, 3, 31)

    for doc in results:
        annotations = doc.get("annotations", {}) \
                         .get("claim-characteristics", {}) \
                         .get("annotations", [])

        for ann in annotations:
            for ans in ann.get("Answer", []):
                rand_date = random_date(start_date, end_date)
                ans["event_date"] = rand_date.strftime("%Y-%m-%d")

    return results

# %%
RISK_MAP = {
    "L": 1,
    "M": 2,
    "H": 3
}

SENTIMENT_WEIGHT = {
    "positive": 1.0,
    "neutral": 0.5,
    "negative": 0.0
}

# %%
from collections import defaultdict

def build_timeline(results):
    timeline = defaultdict(list)

    for doc in results:
        annotations = doc.get("annotations", {}) \
                         .get("claim-characteristics", {}) \
                         .get("annotations", [])

        for ann in annotations:
            risk = RISK_MAP.get(ann.get("RiskCategory", "L"), 1)
            sentiment = SENTIMENT_WEIGHT.get(ann.get("AnnotationType", "neutral"), 0.5)
            keyword = ann.get("Question")

            for ans in ann.get("Answer", []):
                date = ans.get("event_date")
                if not date:
                    continue

                score = risk * sentiment

                timeline[date].append({
                    "score": score,
                    "risk": risk,
                    "keyword": keyword,
                    "sentiment": ann.get("AnnotationType"),
                    "doc_id": doc["id"]
                })

    return timeline

# %%
def aggregate_timeline(timeline):
    aggregated = []

    for date in sorted(timeline.keys()):
        events = timeline[date]

        if not events:
            continue

        avg_score = sum(e["score"] for e in events) / len(events)
        max_score = max(e["score"] for e in events)

        aggregated.append({
            "date": date,
            "avg_score": round(avg_score, 2),
            "max_score": max_score,
            "events": events
        })

    return aggregated

# %%
# !pip install plotly
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/yeshwanth.penukonda/Desktop/Doclens/demo-code/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import plotly.graph_objects as go

def plot_timeline(aggregated):
    dates = [x["date"] for x in aggregated]
    scores = [x["avg_score"] for x in aggregated]

    fig = go.Figure()

    # Add colored background regions
    fig.add_hrect(y0=2, y1=3, fillcolor="red", opacity=0.2, layer="below", line_width=0)
    fig.add_hrect(y0=1, y1=2, fillcolor="yellow", opacity=0.2, layer="below", line_width=0)
    fig.add_hrect(y0=0, y1=1, fillcolor="green", opacity=0.2, layer="below", line_width=0)

    fig.add_trace(go.Scatter(
        x=dates,
        y=scores,
        mode='lines+markers',
        name='Risk Trend',
        line=dict(width=3)
    ))

    # Add event markers (top contributing keyword)
    for point in aggregated:
        top_event = max(point["events"], key=lambda x: x["score"])

        fig.add_trace(go.Scatter(
            x=[point["date"]],
            y=[point["avg_score"]],
            mode='markers',
            marker=dict(size=10),
            name=top_event["keyword"],
            text=f"{top_event['keyword']} ({top_event['sentiment']})",
            hoverinfo='text'
        ))

    fig.update_layout(
        title="Claim Risk Timeline",
        xaxis_title="Date",
        yaxis_title="Risk Score",
        yaxis=dict(
            tickvals=[1, 2, 3],
            ticktext=["Low", "Moderate", "High"], range=[0, 3.5]
        )
    )

    fig.show()

# %%
# !pip install nbformat
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/yeshwanth.penukonda/Desktop/Doclens/demo-code/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# Step 1: Add dates
results_with_dates = add_dates_to_annotations(results)

# Step 2: Build timeline
timeline = build_timeline(results_with_dates)

# Step 3: Aggregate
aggregated = aggregate_timeline(timeline)

# Step 4: Plot
plot_timeline(aggregated)

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# -----------------------------
# INPUT DATA (your API response)
# -----------------------------
data = results  # replace this

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}

# -----------------------------
# STEP 1: SORT DOCUMENTS BY DATE
# -----------------------------
docs = sorted(data, key=lambda x: x["created_at"])

# -----------------------------
# STEP 2: BUILD TIMELINE
# -----------------------------
dates = []
risks = []
annotations_text = []

current_max_risk = 0

for doc in docs:
    date = datetime.fromisoformat(doc["created_at"])
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    # Extract keywords
    keywords = []
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])
    
    for a in ann:
        keyword = a.get("Question") or a.get("Characteristic")
        if keyword:
            keywords.append(keyword)

    # Check if risk increased
    if doc_risk > current_max_risk:
        current_max_risk = doc_risk
        label = ", ".join(set(keywords)) if keywords else "Risk Increased"
    else:
        label = ""

    dates.append(date)
    risks.append(current_max_risk)
    annotations_text.append(label)

# -----------------------------
# STEP 3: PLOT
# -----------------------------
plt.figure(figsize=(12, 6))

plt.plot(dates, risks, marker='o')

# Annotate only where risk increased
for i in range(len(dates)):
    if annotations_text[i]:
        plt.annotate(
            annotations_text[i],
            (dates[i], risks[i]),
            textcoords="offset points",
            xytext=(0,10),
            ha='center'
        )

# -----------------------------
# STEP 4: FORMAT
# -----------------------------
plt.yticks([1, 2, 3], ["Low", "Moderate", "High"])
plt.xlabel("Document Date")
plt.ylabel("Claim Risk")
plt.title("Claim Risk Progression Timeline")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
results = [
        {
            "id": 255,
            "uuid": "9b30326d-3d91-4649-8046-eedf79585597",
            "claim_file": 666,
            "created_at": "2025-03-04T11:20:57.056339+05:30",
            "updated_at": "2025-07-22T19:49:30.362231+05:30",
            "metadata": {},
            "name": "ACORD 2 Automobile Loss Notice.pdf",
            "state": "annotated",
            "risk_info": {
                "document_risk_score": "H"
            },
            "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/9b30326d-3d91-4649-8046-eedf79585597__document_uuid__ACORD_2_Automobile_Loss_Notice.pdf?Expires=1775547255&Signature=e~fsj4Mel7YEM24yRwM933h5hkuxlpOAi4skJmPOidmueW9wi3DSVK3v7NF0dnl6n7PUq2MsxbWgyKaQDm9rK218jB1Q8v7u7hFopwh4dVKmzCd2uQbeVYaR1a~ZC7zebzDJO-2soX8HS-qNtxUn3JbJ5UrhHzCurHP6JnP4zPUB-luWi6E1ww8Qv7tulqGpv9JtY8fdkd~hHfxEI0ukrnfMd-f9tBpcFRPxQEaKXa5nMEBmWnfnpBxKed1H0xapSWRfV05X2bHOL3wUaRpvzQUI1-lWa1azjAQwLAWKLOxUN6EBlOIXXSjaukuhpc8uxsJVgBc-S6BGfFUAa1IJ4A__&Key-Pair-Id=K382VBQQV0CLSN",
            "document_type": "ACORD - Form 2 (AUTOMOBILE LOSS NOTICE)",
            "raw_content_type": "application/pdf",
            "overall_state": "inprogress",
            "annotations": {
                "claim-characteristics": {
                    "annotations": [
                        {
                            "type": "H",
                            "uuid": "5f3e43d9-1458-4fd9-a2fa-56d5059cc933",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "unknown but airlifted from scene",
                                    "context": [
                                        "INJURED INS OTH NAME & ADDRESS PHONE (A/C, No) PED VEH VEH AGE EXTENT OF INJURY Mary Collins unknown but airlifted from scene 35 to Buffalo Medical Center."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.7714422941207886,
                                                "Y": 0.3934762477874756
                                            },
                                            {
                                                "X": 0.959681510925293,
                                                "Y": 0.3933303654193878
                                            },
                                            {
                                                "X": 0.9596965312957764,
                                                "Y": 0.40190914273262024
                                            },
                                            {
                                                "X": 0.7714566588401794,
                                                "Y": 0.40205487608909607
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3933303654193878,
                                            "Left": 0.7714422941207886,
                                            "Width": 0.18825428187847137,
                                            "Height": 0.008724509738385677
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "35 to Buffalo Medical Center. WITNESSES OR PASSENGERS INS OTH NAME & ADDRESS PHONE (A/C, No) VEH VEH OTHER (Specify) Terry Thompson 556-978-2341 Driver of vehicle following IV stopped to assit. REPORTED BY REPORTED TO Jimmy Peterson Peter Jackson REMARKS (ACORD 101, Additional Remarks Schedule, may be attached if more",
                                        "prev": "ADDRESS: Not avaialbe SECONDARY E-MAIL ADDRESS: DRIVER'S NAME AND ADDRESS (Check if same as owner) PRIMARY HOME BUS CELL SECONDARY PHONE # HOME BUS CELL PHONE # PRIMARY E-MAIL ADDRESS: SECONDARY E-MAIL ADDRESS: DESCRIBE DAMAGE Significant damage to rear and driver side. ESTIMATE AMOUNT WHERE CAN DAMAGE BE SEEN? Unknown Towed from accident scene by Roadside Towing. INJURED INS OTH NAME & ADDRESS PHONE (A/C, No) PED VEH VEH AGE EXTENT OF INJURY Mary Collins ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Airlifted",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "6f64bdf7-5960-4fd7-81e8-707532bf4af5",
                            "Answer": [
                                {
                                    "page": 3,
                                    "score": 1.0,
                                    "answer": "to a settlement or award payable for insurance proceeds shall be reported to the Colorado Division of Insurance within the Department of",
                                    "context": [
                                        "Any insurance company or agent of an insurance company who knowingly provides false, incomplete, or misleading facts or information to a policyholder or claimant for the purpose of defrauding or attempting to defraud the policyholder or claimant with regard to a settlement or award payable for insurance proceeds shall be reported to the Colorado Division of Insurance within the Department of Regulatory Agencies."
                                    ],
                                    "is_true": "junk",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.046197980642318726,
                                                "Y": 0.34787455201148987
                                            },
                                            {
                                                "X": 0.9519292116165161,
                                                "Y": 0.34745144844055176
                                            },
                                            {
                                                "X": 0.9519388675689697,
                                                "Y": 0.35884615778923035
                                            },
                                            {
                                                "X": 0.04620346426963806,
                                                "Y": 0.3592665195465088
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.34745144844055176,
                                            "Left": 0.046197980642318726,
                                            "Width": 0.9057408571243286,
                                            "Height": 0.011815058998763561
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Regulatory Agencies. Applicable in Delaware: Any person who knowingly, and with intent to injure, defraud or deceive any insurer, files a statement of claim containing any false, incomplete or misleading information is guilty of a felony. Applicable in the District of Columbia: WARNING: It is a crime to provide false",
                                        "prev": "to knowingly provide false, incomplete, or misleading facts or information to an insurance company for the purpose of defrauding or attempting to defraud the company. Penalties may include imprisonment, fines, denial of insurance and civil damages. Any insurance company or agent of an insurance company who knowingly provides false, incomplete, or misleading facts or information to a policyholder or claimant for the purpose of defrauding or attempting to defraud the policyholder or claimant with regard ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        }
                    ]
                }
            }
        },
        {
            "id": 259,
            "uuid": "004071a4-17dd-4004-b451-15d3fb9bbce5",
            "claim_file": 666,
            "created_at": "2025-03-04T11:46:12.321819+05:30",
            "updated_at": "2025-03-04T11:50:53.129316+05:30",
            "metadata": {},
            "name": "Brooks and Crooks.pdf",
            "state": "annotated",
            "risk_info": {
                "document_risk_score": "H"
            },
            "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/004071a4-17dd-4004-b451-15d3fb9bbce5__document_uuid__Brooks_and_Crooks.pdf?Expires=1775547255&Signature=QT0pczmwY4nLq6iQsxFU8qeCu-cVDOZAW-e8a2Br3BvlQxt~bgXluKaxgzrgtTil0ZPqo8J6O5oKFz1kXNHdwL47PHANE0parjeyE68krJiO5Yr8C8-jOMzpEmvr4Qww85R9EJJZN3fuzmPRRjTxVmWr2EBzvz5XX9Cm7V2ANPMCNJ0mpZtiGP9u-UoIKgr6BV-U8y2RfXEW9b9WK5AY4zCXuUzasQFqH~77jj9wxrTMC0nAWgMjOSPeCJegLEB3lHjY2qo4iQ9UUbuGJPScbqIb48lCgchnxL-bK-vYinPvK-uWKL1HpP7MW20TJrniVsPYJw3J-zvzjEkkgAQ3FA__&Key-Pair-Id=K382VBQQV0CLSN",
            "document_type": "Demand Package",
            "raw_content_type": "application/pdf",
            "overall_state": "inprogress",
            "annotations": {
                "claim-characteristics": {
                    "annotations": [
                        {
                            "type": "H",
                            "uuid": "22f1dc20-132b-46ef-a11a-31dd351769d1",
                            "Answer": [
                                {
                                    "page": 1,
                                    "score": 1.0,
                                    "answer": "from the impact with the interior of the vehicle. Mrs. Collins was airlifted from the scene of the",
                                    "context": [
                                        "Mrs. Collins was airlifted from the scene of the accident to Buffalo Medical Center."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11694281548261642,
                                                "Y": 0.7038566470146179
                                            },
                                            {
                                                "X": 0.86053866147995,
                                                "Y": 0.7042073607444763
                                            },
                                            {
                                                "X": 0.8605417013168335,
                                                "Y": 0.7183322906494141
                                            },
                                            {
                                                "X": 0.11694320291280746,
                                                "Y": 0.7179800271987915
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7038566470146179,
                                            "Left": 0.11694281548261642,
                                            "Width": 0.7435988783836365,
                                            "Height": 0.014475679956376553
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "accident to Buffalo Medical Center. She was examined in the emergency room by Dr. William Thomas who confirmed her injuries were related to the accident. Unfortunately, her conditions did not improve and 10 days later she was examined at the Buffalo Neuroscience Center by Dr. Katherine Coleman, a neurologist. Dr.Coleman",
                                        "prev": "the truck cab as he approached the junction. Peterson clearly had time to adjust his speed to allow a safe merger but failed to give Mrs. Collins sufficient room to merge. Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a punitive damage claim. Mary Collins sustained significant injuries in the accident. She had bruises on her upper body ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Airlifted",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "H",
                            "uuid": "b733379f-2cd7-4557-9665-9281aa24aca7",
                            "Answer": [
                                {
                                    "page": 1,
                                    "score": 1.0,
                                    "answer": "has now diagnosed her with a moderate permanent brain injury resulting from the accident. In",
                                    "context": [
                                        "Dr.Coleman has continued to monitor and treat Mrs. Collins has now diagnosed her with a moderate permanent brain injury resulting from the accident."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11767275631427765,
                                                "Y": 0.7956950068473816
                                            },
                                            {
                                                "X": 0.8648175597190857,
                                                "Y": 0.7960575819015503
                                            },
                                            {
                                                "X": 0.864820659160614,
                                                "Y": 0.8102584481239319
                                            },
                                            {
                                                "X": 0.11767315119504929,
                                                "Y": 0.8098942637443542
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7956950068473816,
                                            "Left": 0.11767275631427765,
                                            "Width": 0.7471478581428528,
                                            "Height": 0.014563499018549919
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain. Mr. Collins has had pain in her back and suffered from persistent headaches since the day of the accident. Mrs. Collins is entitled to significant compensation for the permanent and painful injuries she suffered when your insured",
                                        "prev": "the impact with the interior of the vehicle. Mrs. Collins was airlifted from the scene of the accident to Buffalo Medical Center. She was examined in the emergency room by Dr. William Thomas who confirmed her injuries were related to the accident. Unfortunately, her conditions did not improve and 10 days later she was examined at the Buffalo Neuroscience Center by Dr. Katherine Coleman, a neurologist. Dr.Coleman has continued to monitor and treat Mrs. Collins ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Brain Injury",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "H",
                            "uuid": "b5f67edc-da70-43c4-aced-3e8b72f8ef3a",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "Continued monitoring, treatment and therapy for permanent brain injury $1,000,000",
                                    "context": [
                                        "Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment and therapy for permanent brain injury $1,000,000 Surgery for lower back to relieve pain and subsequent physical therapy $200,000 In addition, Mrs. Collins has been unable to return to her job as a human resources manager."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.17614233493804932,
                                                "Y": 0.42310023307800293
                                            },
                                            {
                                                "X": 0.8368291854858398,
                                                "Y": 0.4233376383781433
                                            },
                                            {
                                                "X": 0.8368356823921204,
                                                "Y": 0.43794262409210205
                                            },
                                            {
                                                "X": 0.1761447787284851,
                                                "Y": 0.43770381808280945
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.42310023307800293,
                                            "Left": 0.17614233493804932,
                                            "Width": 0.6606932878494263,
                                            "Height": 0.014842402189970016
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Surgery for lower back to relieve pain and subsequent physical therapy $200,000 In addition, Mrs. Collins has been unable to return to her job as a human resources manager. Her compensation before the accident was $75,000. It is very unlikely Mrs. Collins will be able to return to work. At",
                                        "prev": "likely to be permanent and will impact their relationship for many years to come. Thus, Mr. Collins is entitled to compensation for his loss of society and consortium. Economic Damages Mary Collins has incurred $80,000 in medical expenses to date. The cost for future care related to injuries is $1,200,000. Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Brain Injury",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "567073db-9525-4179-8974-f9d83575847a",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "loss of society and consortium.",
                                    "context": [
                                        "Thus, Mr. Collins is entitled to compensation for his loss of society and consortium."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11753345280885696,
                                                "Y": 0.1848616898059845
                                            },
                                            {
                                                "X": 0.3617483675479889,
                                                "Y": 0.1849411576986313
                                            },
                                            {
                                                "X": 0.3617517650127411,
                                                "Y": 0.19882415235042572
                                            },
                                            {
                                                "X": 0.11753542721271515,
                                                "Y": 0.19874419271945953
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.1848616898059845,
                                            "Left": 0.11753345280885696,
                                            "Width": 0.24421830475330353,
                                            "Height": 0.01396246999502182
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Economic Damages Mary Collins has incurred $80,000 in medical expenses to date. The cost for future care related to injuries is $1,200,000. Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment",
                                        "prev": "road. The relationship between Mary and James Collins has changed significantly following the accident. Prior to the accident Mary and James enjoyed each other's company with frequent travel and a fulfilling intimate relationship. Since the accident the couple has not been able to continue the same level of activity. These changes are likely to be permanent and will impact their relationship for many years to come. Thus, Mr. Collins is entitled to compensation for his ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Loss of Society",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "2041d066-4872-43fd-9125-88c3460c79af",
                            "Answer": [
                                {
                                    "page": 1,
                                    "score": 1.0,
                                    "answer": "addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain.",
                                    "context": [
                                        "In addition, Dr. Coleman has recommended surgery to address the continued lumbar back pain."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11729932576417923,
                                                "Y": 0.8137573003768921
                                            },
                                            {
                                                "X": 0.8558980226516724,
                                                "Y": 0.8141177296638489
                                            },
                                            {
                                                "X": 0.8559010624885559,
                                                "Y": 0.8283629417419434
                                            },
                                            {
                                                "X": 0.11729972064495087,
                                                "Y": 0.8280009627342224
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.8137573003768921,
                                            "Left": 0.11729932576417923,
                                            "Width": 0.7386017441749573,
                                            "Height": 0.014605680480599403
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Mr. Collins has had pain in her back and suffered from persistent headaches since the day of the accident. Mrs. Collins is entitled to significant compensation for the permanent and painful injuries she suffered when your insured negligently ran her off the road. The relationship between Mary and James Collins",
                                        "prev": "of the accident to Buffalo Medical Center. She was examined in the emergency room by Dr. William Thomas who confirmed her injuries were related to the accident. Unfortunately, her conditions did not improve and 10 days later she was examined at the Buffalo Neuroscience Center by Dr. Katherine Coleman, a neurologist. Dr.Coleman has continued to monitor and treat Mrs. Collins has now diagnosed her with a moderate permanent brain injury resulting from the accident. In ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Surgery",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "bbef47e7-474a-4ade-8d5e-0ea2ad840720",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "Surgery for lower back to relieve pain and subsequent physical therapy $200,000",
                                    "context": [
                                        "Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment and therapy for permanent brain injury $1,000,000 Surgery for lower back to relieve pain and subsequent physical therapy $200,000 In addition, Mrs. Collins has been unable to return to her job as a human resources manager."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.1761813908815384,
                                                "Y": 0.44151678681373596
                                            },
                                            {
                                                "X": 0.819591760635376,
                                                "Y": 0.4417496919631958
                                            },
                                            {
                                                "X": 0.8195981979370117,
                                                "Y": 0.4564182460308075
                                            },
                                            {
                                                "X": 0.17618383467197418,
                                                "Y": 0.4561839997768402
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.44151678681373596,
                                            "Left": 0.1761813908815384,
                                            "Width": 0.6434168219566345,
                                            "Height": 0.014901469461619854
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "In addition, Mrs. Collins has been unable to return to her job as a human resources manager. Her compensation before the accident was $75,000. It is very unlikely Mrs. Collins will be able to return to work. At the time of the accident she had a work life expectancy of",
                                        "prev": "many years to come. Thus, Mr. Collins is entitled to compensation for his loss of society and consortium. Economic Damages Mary Collins has incurred $80,000 in medical expenses to date. The cost for future care related to injuries is $1,200,000. Past Medical Expenses Buffalo Medical Center $30,000 Neuroscience Center of Buffalo $35,000 Emergency Airlift and Miscellaneous prescription and medical devices $15,000 Future Estimated Medical Expenses Continued monitoring, treatment and therapy for permanent brain injury $1,000,000 ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Surgery",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "H",
                            "uuid": "30e7ff53-d866-4d60-977f-a647f8421868",
                            "Answer": [
                                {
                                    "page": 1,
                                    "score": 1.0,
                                    "answer": "will be amending our Complaint to assert that this is a case of distracted driving that supports a",
                                    "context": [
                                        "Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a punitive damage claim."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.1170368418097496,
                                                "Y": 0.6303526759147644
                                            },
                                            {
                                                "X": 0.8699946403503418,
                                                "Y": 0.630699634552002
                                            },
                                            {
                                                "X": 0.8699976801872253,
                                                "Y": 0.6446036100387573
                                            },
                                            {
                                                "X": 0.11703722923994064,
                                                "Y": 0.6442551612854004
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.6303526759147644,
                                            "Left": 0.1170368418097496,
                                            "Width": 0.7529608011245728,
                                            "Height": 0.014250941574573517
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "punitive damage claim. Mary Collins sustained significant injuries in the accident. She had bruises on her upper body from the impact with the interior of the vehicle. Mrs. Collins was airlifted from the scene of the accident to Buffalo Medical Center. She was examined in the emergency room by Dr.",
                                        "prev": "a safe distance. Recently we obtained video from a traffic control camera at the junction. The video clearly shows the accident and reveals that Peterson was both on the cell-phone and looking at a screen in the truck cab as he approached the junction. Peterson clearly had time to adjust his speed to allow a safe merger but failed to give Mrs. Collins sufficient room to merge. Clearly your insured was at fault and we ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Distracted driving",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "H",
                            "uuid": "a23b7387-458a-44e2-8fae-066a2d01d3f4",
                            "Answer": [
                                {
                                    "page": 3,
                                    "score": 1.0,
                                    "answer": "Affidavit confirming that there is no other potentially available insurance coverage and that",
                                    "context": [
                                        "We also require an Affidavit confirming that there is no other potentially available insurance coverage and that Peterson Trucking and Jimmy Peterson do not have liquid assets in excess of $3,000,000."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11698218435049057,
                                                "Y": 0.1843317747116089
                                            },
                                            {
                                                "X": 0.8320776224136353,
                                                "Y": 0.18509793281555176
                                            },
                                            {
                                                "X": 0.8320637345314026,
                                                "Y": 0.19965265691280365
                                            },
                                            {
                                                "X": 0.11696328222751617,
                                                "Y": 0.19888819754123688
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.1843317747116089,
                                            "Left": 0.11696328222751617,
                                            "Width": 0.7151143550872803,
                                            "Height": 0.015320890583097935
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Peterson Trucking and Jimmy Peterson do not have liquid assets in excess of $3,000,000. Payment should be made by check or wire transfer payable to the Brooks and Crooks Client Trust Account. Please contact us for specific payment information. Payment must be sent to my attention and received prior to",
                                        "prev": "clients would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including potential bad faith claims against Best Value Insurance. Mrs and Mr. Collins make this final offer to resolve their claims for the full $3,000,000 policy limits provided payment is made within 28 days from the date of this letter. We also require an ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Affidavit",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "H",
                            "uuid": "e5150af1-3140-4684-94e6-efad7ee69b16",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients",
                                    "context": [
                                        "This failure to respond is a clear indication of bad faith claim handling."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11717701703310013,
                                                "Y": 0.84578937292099
                                            },
                                            {
                                                "X": 0.8444548845291138,
                                                "Y": 0.8460944890975952
                                            },
                                            {
                                                "X": 0.8444610834121704,
                                                "Y": 0.8600010871887207
                                            },
                                            {
                                                "X": 0.11717899143695831,
                                                "Y": 0.8596944808959961
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.84578937292099,
                                            "Left": 0.11717701703310013,
                                            "Width": 0.7272840738296509,
                                            "Height": 0.014211717061698437
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including potential bad faith claims against Best Value Insurance. Mrs and Mr. Collins make this final offer to resolve their",
                                        "prev": "negligence altered forever. Based upon the prior communication from you we understand that the applicable policy limits are $3,000,000 and that there is no excess coverage. Please advise us immediately if our understanding of policy limits and available coverage is not correct. The settlement offer in this letter is void if this understanding is not correct. As you know, our clients made a prior offer to settle and received no response from you or your ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Bad faith",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "H",
                            "uuid": "9fb5a04c-38ae-4213-a3b3-0226c04171f8",
                            "Answer": [
                                {
                                    "page": 3,
                                    "score": 1.0,
                                    "answer": "potential bad faith claims against Best Value Insurance.",
                                    "context": [
                                        "Our clients would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including potential bad faith claims against Best Value Insurance."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11757465451955795,
                                                "Y": 0.11125008761882782
                                            },
                                            {
                                                "X": 0.5562009215354919,
                                                "Y": 0.11172531545162201
                                            },
                                            {
                                                "X": 0.5561854839324951,
                                                "Y": 0.1259336620569229
                                            },
                                            {
                                                "X": 0.11755619943141937,
                                                "Y": 0.1254594624042511
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.11125008761882782,
                                            "Left": 0.11755619943141937,
                                            "Width": 0.4386447072029114,
                                            "Height": 0.014683570712804794
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Mrs and Mr. Collins make this final offer to resolve their claims for the full $3,000,000 policy limits provided payment is made within 28 days from the date of this letter. We also require an Affidavit confirming that there is no other potentially available insurance coverage and that Peterson Trucking",
                                        "prev": "letter is void if this understanding is not correct. As you know, our clients made a prior offer to settle and received no response from you or your insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Bad faith",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "H",
                            "uuid": "aca916d1-2318-46a0-9938-bea697675701",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "As you know, our clients made a prior offer to settle and received no response from you or your",
                                    "context": [
                                        "As you know, our clients made a prior offer to settle and received no response from you or your insureds."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11681824922561646,
                                                "Y": 0.8272852301597595
                                            },
                                            {
                                                "X": 0.8721499443054199,
                                                "Y": 0.8276001811027527
                                            },
                                            {
                                                "X": 0.8721565008163452,
                                                "Y": 0.8419685959815979
                                            },
                                            {
                                                "X": 0.11682029068470001,
                                                "Y": 0.8416520953178406
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.8272852301597595,
                                            "Left": 0.11681824922561646,
                                            "Width": 0.7553382515907288,
                                            "Height": 0.014683324843645096
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients would prefer to get his case resolved without further delay and, therefore they make the following offer but if the claim is not resolved, our clients will pursue all options, including potential bad faith",
                                        "prev": "with his wife. Mr. Collins is confident a jury will award him significant compensation for the relationship your insured's negligence altered forever. Based upon the prior communication from you we understand that the applicable policy limits are $3,000,000 and that there is no excess coverage. Please advise us immediately if our understanding of policy limits and available coverage is not correct. The settlement offer in this letter is void if this understanding is not correct. ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Offer to Settle",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "H",
                            "uuid": "9918b902-c4ec-4984-ae0f-756ae4f14b4d",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "understanding of policy limits and available coverage is not correct. The settlement offer in this",
                                    "context": [
                                        "The settlement offer in this letter is void if this understanding is not correct."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11732728034257889,
                                                "Y": 0.7723630666732788
                                            },
                                            {
                                                "X": 0.8662427067756653,
                                                "Y": 0.7726694941520691
                                            },
                                            {
                                                "X": 0.8662492036819458,
                                                "Y": 0.7869805097579956
                                            },
                                            {
                                                "X": 0.11732932180166245,
                                                "Y": 0.7866725921630859
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7723630666732788,
                                            "Left": 0.11732728034257889,
                                            "Width": 0.7489219307899475,
                                            "Height": 0.014617422595620155
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "letter is void if this understanding is not correct. As you know, our clients made a prior offer to settle and received no response from you or your insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients would prefer to get his case",
                                        "prev": "well over $1,000,000 in compensation for her pain and suffering. In addition, Mr. Collins is entitled to compensation for the loss of his relationship with his wife. Mr. Collins is confident a jury will award him significant compensation for the relationship your insured's negligence altered forever. Based upon the prior communication from you we understand that the applicable policy limits are $3,000,000 and that there is no excess coverage. Please advise us immediately if our ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement Offer",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "a3953deb-dc37-4c13-845d-8376bc28a804",
                            "Answer": [
                                {
                                    "page": 3,
                                    "score": 1.0,
                                    "answer": "your insured. Any counter-offer will be considered a rejection of this offer and this offer will no",
                                    "context": [
                                        "Any counter-offer will be considered a rejection of this offer and this offer will no longer be available."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.1170664057135582,
                                                "Y": 0.3863273859024048
                                            },
                                            {
                                                "X": 0.8604476451873779,
                                                "Y": 0.38709914684295654
                                            },
                                            {
                                                "X": 0.8604339361190796,
                                                "Y": 0.4017188251018524
                                            },
                                            {
                                                "X": 0.11704742163419724,
                                                "Y": 0.4009488523006439
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3863273859024048,
                                            "Left": 0.11704742163419724,
                                            "Width": 0.7434002161026001,
                                            "Height": 0.015391429886221886
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "longer be available. Please give this offer careful consideration as it is the last opportunity to settle within policy limits. Albert Crooks Albert Crooks, ESQ. Bar Number 378952 Brooks & Crooks At Law",
                                        "prev": "October 24, 2024. The payment may not be contingent on resolution of any liens. If your insured requires a release, Mrs and Mr. Collins will execute a standard claim release upon receipt of the funds. Failure to accept this offer will result in an amended complaint seeking punitive damages and exposing your insured to excess or uncovered liability. Please forward this letter to your insureds. We look forward to a prompt response from you or ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Counter offer",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "e71db55b-2942-4a23-9c84-dfe9ffbf8359",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "understanding of policy limits and available coverage is not correct. The settlement offer in this",
                                    "context": [
                                        "The settlement offer in this letter is void if this understanding is not correct."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11732728034257889,
                                                "Y": 0.7723630666732788
                                            },
                                            {
                                                "X": 0.8662427067756653,
                                                "Y": 0.7726694941520691
                                            },
                                            {
                                                "X": 0.8662492036819458,
                                                "Y": 0.7869805097579956
                                            },
                                            {
                                                "X": 0.11732932180166245,
                                                "Y": 0.7866725921630859
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7723630666732788,
                                            "Left": 0.11732728034257889,
                                            "Width": 0.7489219307899475,
                                            "Height": 0.014617422595620155
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "letter is void if this understanding is not correct. As you know, our clients made a prior offer to settle and received no response from you or your insureds. This failure to respond is a clear indication of bad faith claim handling. Our clients would prefer to get his case",
                                        "prev": "well over $1,000,000 in compensation for her pain and suffering. In addition, Mr. Collins is entitled to compensation for the loss of his relationship with his wife. Mr. Collins is confident a jury will award him significant compensation for the relationship your insured's negligence altered forever. Based upon the prior communication from you we understand that the applicable policy limits are $3,000,000 and that there is no excess coverage. Please advise us immediately if our ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "86d15e96-e306-4b5b-8215-8cd289e2b39c",
                            "Answer": [
                                {
                                    "page": 1,
                                    "score": 1.0,
                                    "answer": "punitive damage claim.",
                                    "context": [
                                        "Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a punitive damage claim."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11778978258371353,
                                                "Y": 0.6490494608879089
                                            },
                                            {
                                                "X": 0.3000323176383972,
                                                "Y": 0.6491339206695557
                                            },
                                            {
                                                "X": 0.3000333309173584,
                                                "Y": 0.6630092263221741
                                            },
                                            {
                                                "X": 0.11779017001390457,
                                                "Y": 0.6629244089126587
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.6490494608879089,
                                            "Left": 0.11778978258371353,
                                            "Width": 0.18224355578422546,
                                            "Height": 0.013959759846329689
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Mary Collins sustained significant injuries in the accident. She had bruises on her upper body from the impact with the interior of the vehicle. Mrs. Collins was airlifted from the scene of the accident to Buffalo Medical Center. She was examined in the emergency room by Dr. William Thomas who",
                                        "prev": "shows the accident and reveals that Peterson was both on the cell-phone and looking at a screen in the truck cab as he approached the junction. Peterson clearly had time to adjust his speed to allow a safe merger but failed to give Mrs. Collins sufficient room to merge. Clearly your insured was at fault and we will be amending our Complaint to assert that this is a case of distracted driving that supports a ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "punitive",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "7656be9a-917a-47a9-8c90-573840e8cec0",
                            "Answer": [
                                {
                                    "page": 3,
                                    "score": 1.0,
                                    "answer": "in an amended complaint seeking punitive damages and exposing your insured to excess or",
                                    "context": [
                                        "Failure to accept this offer will result in an amended complaint seeking punitive damages and exposing your insured to excess or uncovered liability."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11757682263851166,
                                                "Y": 0.3128148317337036
                                            },
                                            {
                                                "X": 0.8485113978385925,
                                                "Y": 0.31358250975608826
                                            },
                                            {
                                                "X": 0.8484980463981628,
                                                "Y": 0.32773178815841675
                                            },
                                            {
                                                "X": 0.11755844205617905,
                                                "Y": 0.3269658088684082
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3128148317337036,
                                            "Left": 0.11755844205617905,
                                            "Width": 0.7309529185295105,
                                            "Height": 0.014916958287358284
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "uncovered liability. Please forward this letter to your insureds. We look forward to a prompt response from you or your insured. Any counter-offer will be considered a rejection of this offer and this offer will no longer be available. Please give this offer careful consideration as it is the last",
                                        "prev": "or wire transfer payable to the Brooks and Crooks Client Trust Account. Please contact us for specific payment information. Payment must be sent to my attention and received prior to 5:00 pm on October 24, 2024. The payment may not be contingent on resolution of any liens. If your insured requires a release, Mrs and Mr. Collins will execute a standard claim release upon receipt of the funds. Failure to accept this offer will result ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "punitive",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        }
                    ]
                }
            }
        },
        {
            "id": 257,
            "uuid": "a356147b-e649-4c94-bc55-d8754b50c7e0",
            "claim_file": 666,
            "created_at": "2025-03-04T11:27:23.056152+05:30",
            "updated_at": "2025-03-04T11:29:24.760020+05:30",
            "metadata": {},
            "name": "Complaint Supreme Court NY.pdf",
            "state": "annotated",
            "risk_info": {
                "document_risk_score": "H"
            },
            "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/a356147b-e649-4c94-bc55-d8754b50c7e0__document_uuid__Complaint_Supreme_Court_NY.pdf?Expires=1775547255&Signature=ITb8zBUlxbWTY5ZDpfpaDo9AeEr79vNnIi3iGdeg8fJxgvw3fwF~-EQKf06nekuE-~Xh3HXxJftP1go1SyGS2tF6cWVMwg0UwI04Ypph6~y1wN28tKixgrirYODVk2Dw5rFQuAmZa6WwbV~Yjsu8Z6EQzi5KSuENaq2TG1~4srma2-A56WcFvHLMdAJEL1mvpneHZU3o4PRguyQIA7irJ7UNEApt6SdLvEREC1TuHTBA~Ejc9CvPPTDf6a5F1Vnj2Sbve5Hg-OeXHo-TFLjM0wXbtEMimvHcE4Qnc30huKG5zm61qo4thdDbFqBEaVNe6kRt9T15tmw1o8QSqZAUiw__&Key-Pair-Id=K382VBQQV0CLSN",
            "document_type": "Complaint Report",
            "raw_content_type": "application/pdf",
            "overall_state": "inprogress",
            "annotations": {
                "claim-characteristics": {
                    "annotations": [
                        {
                            "type": "H",
                            "uuid": "413c00c4-a54a-4c8e-8245-177e4f60adbc",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "12. Plaintiff, Mary Collins, was severely injured in the accident and had to be airlifted from",
                                    "context": [],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.14788773655891418,
                                                "Y": 0.30047255754470825
                                            },
                                            {
                                                "X": 0.8548818230628967,
                                                "Y": 0.3006229102611542
                                            },
                                            {
                                                "X": 0.854884684085846,
                                                "Y": 0.3145325183868408
                                            },
                                            {
                                                "X": 0.1478874385356903,
                                                "Y": 0.314381867647171
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.30047255754470825,
                                            "Left": 0.1478874385356903,
                                            "Width": 0.7069972157478333,
                                            "Height": 0.014059987850487232
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "the scene to Buffalo Medical Center for immediate treatment. 13. As a result of the accident Mary Collins has suffered significant and permanent injuries to her body, including but not limited to a brain injury and injuries to her lumbar spine. 14. As a result of the accident Mary Collins",
                                        "prev": "Plaintiff's vehicle. 9. Defendant Jimmy Peterson's negligence caused the truck to forcefully strike the rear-end of the Plaintiffs' vehicle. Defendant Peterson Trucking is liable for the acts and omissions or its employee, owner or agent, Jimmy Peterson. 10. As a result of the contact by Defendant's vehicle, Plaintiff's vehicle was forced into a retaining wall along the highway. 11. Defendants' negligence, directly and proximately caused serious and permanent injury to Plaintiffs. Count I Mary Collins ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Airlifted",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "H",
                            "uuid": "81221c08-9031-4431-ab94-5f1a2223f602",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "to her body, including but not limited to a brain injury and injuries to her lumbar spine.",
                                    "context": [
                                        "As a result of the accident Mary Collins has suffered significant and permanent injuries to her body, including but not limited to a brain injury and injuries to her lumbar spine."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.1752580851316452,
                                                "Y": 0.3644663095474243
                                            },
                                            {
                                                "X": 0.8493260145187378,
                                                "Y": 0.3646109998226166
                                            },
                                            {
                                                "X": 0.849328875541687,
                                                "Y": 0.3785967230796814
                                            },
                                            {
                                                "X": 0.17525790631771088,
                                                "Y": 0.37845176458358765
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3644663095474243,
                                            "Left": 0.17525790631771088,
                                            "Width": 0.6740709543228149,
                                            "Height": 0.014130386523902416
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "14. As a result of the accident Mary Collins has and will incur significant medical expenses, has not been able to return to work, has not been able to enjoy life and has endured daily pain and suffering. These conditions will continue into the future. 15. As compensation for her",
                                        "prev": "result of the contact by Defendant's vehicle, Plaintiff's vehicle was forced into a retaining wall along the highway. 11. Defendants' negligence, directly and proximately caused serious and permanent injury to Plaintiffs. Count I Mary Collins 12. Plaintiff, Mary Collins, was severely injured in the accident and had to be airlifted from the scene to Buffalo Medical Center for immediate treatment. 13. As a result of the accident Mary Collins has suffered significant and permanent injuries ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Brain Injury",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "8eb41d0e-a926-42aa-a926-67059b84c225",
                            "Answer": [
                                {
                                    "page": 2,
                                    "score": 1.0,
                                    "answer": "20. Plaintiff, James Collins seeks compensation for his loss of society, companionship and",
                                    "context": [],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.14690615236759186,
                                                "Y": 0.7313841581344604
                                            },
                                            {
                                                "X": 0.8605656027793884,
                                                "Y": 0.7315452694892883
                                            },
                                            {
                                                "X": 0.8605685830116272,
                                                "Y": 0.7459099888801575
                                            },
                                            {
                                                "X": 0.1469058394432068,
                                                "Y": 0.7457485795021057
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7313841581344604,
                                            "Left": 0.1469058394432068,
                                            "Width": 0.7136627435684204,
                                            "Height": 0.01452584844082594
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "consortium in an amount in excess of the jurisdictional minimum. Jury Demand Plaintiffs demand a trial by a jury. Submitted Albert Crooks Albert Crooks, ESQ. Bar Number 378952 Brooks & Crooks At Law Attorney for Plaintiffs",
                                        "prev": "Collins and Mary Collins are husband and wife. 17. Prior to the accident caused by the Defendants, Plaintiff James Collins enjoyed a wonderful, loving and fulfilling relationship with Mary Collins. 18. As a result of the accident, Mary Collins has not been able to participate in the activities that the couple enjoyed before the accident. 19. As a result of the accident James Collins has been deprived of the relationship with his wife, Mary Collins. ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Loss of Society",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        }
                    ]
                }
            }
        },
        {
            "id": 845,
            "uuid": "24141b70-2adf-4a02-ab0b-f35a8f1b12a1",
            "claim_file": 666,
            "created_at": "2025-07-07T12:01:12.898388+05:30",
            "updated_at": "2025-07-07T16:10:52.292920+05:30",
            "metadata": {},
            "name": "Document Scan Oct 11 2024.pdf",
            "state": "annotated",
            "risk_info": {
                "document_risk_score": "L"
            },
            "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/24141b70-2adf-4a02-ab0b-f35a8f1b12a1__document_uuid__Document_Scan_Oct_11_2024.pdf?Expires=1775547255&Signature=JHlMuYHt4pqIWk5440FJ5GUsjbXfkyMAVyxTkm3xT-hW~3SVLiIUlr0gWg0RUuGJ-YiCuHuEK6LEvICAEer8Akq1MBslv48VvUoTt7~-~qJsI61yBa5ggceNBR73~WaWpVWf~hMgfUwwLOHseMPCDHu4b1obqNjgqiOtesGlSEDXrSrVkTZrHevH3p53ldOvZsOGpS8~QBeU7-LQg7-kDf80esR-Om8ejj869MRLG-dAObLnNqQnX8b7kN6ytqyAIWwnKhPCim4fpzEgHDiwZOH-jxjhKLSo33~BmYEWyY8y8iqvXoyQq87zglOjGG~ZdHUlUiKkFh~ZgFhBmjFzNg__&Key-Pair-Id=K382VBQQV0CLSN",
            "document_type": "Accident Report",
            "raw_content_type": "application/pdf",
            "overall_state": "inprogress",
            "annotations": {
                "claim-characteristics": {
                    "annotations": []
                }
            }
        },
        {
            "id": 846,
            "uuid": "9513f867-3058-46ce-ad46-d8bbb9e651c0",
            "claim_file": 666,
            "created_at": "2025-07-07T14:16:09.879120+05:30",
            "updated_at": "2025-07-07T16:10:52.579207+05:30",
            "metadata": {},
            "name": "HCC Policy Procida.pdf",
            "state": "annotated",
            "risk_info": {
                "document_risk_score": "H"
            },
            "pdf_file": "https://d23wsbfp7zswgt.cloudfront.net/9513f867-3058-46ce-ad46-d8bbb9e651c0__document_uuid__HCC_Policy_Procida.pdf?Expires=1775547255&Signature=NW7bDQdAnhNeOUmsEMan9O1itwiU0oavsJdl0384RkIv-vsnDDc~rBYuH-RzuV55d2ix-9C2c~nuCDlNY~u8j6oU~UKpVPj-rj89Mpsuv64d-g5hvTs2tij7u6PbO8NOzx9Sq3l-OI3uDE-njUfg6E0DJG855khdHfvAHeT5JzqihcuCEkEUdP0BZ~HabwVbgWtm1dTW4t5J1bnyRnEgccajt0OCEdTdRIeMDdpavxIWqme0f7xBTchQixZuPuf1HwT8MBhO7t4GZyvieRRElzJZYeZxrBaPGux4t65bFtG1myF58Rz0VixszwNHHKF8BiXW155LWZoU5iwOJ4W-TQ__&Key-Pair-Id=K382VBQQV0CLSN",
            "document_type": "Policy Declaration Report",
            "raw_content_type": "application/pdf",
            "overall_state": "inprogress",
            "annotations": {
                "claim-characteristics": {
                    "annotations": [
                        {
                            "type": "H",
                            "uuid": "8ad9acda-8d8a-4643-809c-86c7c23ffe75",
                            "Answer": [
                                {
                                    "page": 30,
                                    "score": 1.0,
                                    "answer": "(3) \"Impaired property\";",
                                    "context": [
                                        "A separate (3) \"Impaired property\"; limit of insurance applies to Damage To Prem- ises Rented To You as described in Section III if such product, work, or property is withdrawn - Limits Of Insurance."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5631603598594666,
                                                "Y": 0.2948035001754761
                                            },
                                            {
                                                "X": 0.7365636825561523,
                                                "Y": 0.2948024868965149
                                            },
                                            {
                                                "X": 0.7365636825561523,
                                                "Y": 0.30781686305999756
                                            },
                                            {
                                                "X": 0.5631603598594666,
                                                "Y": 0.30781784653663635
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.2948024868965149,
                                            "Left": 0.5631603598594666,
                                            "Width": 0.1734033226966858,
                                            "Height": 0.013015332631766796
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "limit of insurance applies to Damage To Prem- ises Rented To You as described in Section III if such product, work, or property is withdrawn - Limits Of Insurance. or recalled from the market or from use by any person or organization because of a known or Paragraph (2) of",
                                        "prev": "pense incurred by you or others for the loss of formed on it. use, withdrawal, recall, inspection, repair, re- Paragraphs (1), (3) and (4) of this exclusion do placement, adjustment, removal or disposal of: not apply to \"property damage\" (other than (1) \"Your product\"; damage by fire) to premises, including the con- tents of such premises, rented to you for a pe- (2) \"Your work\"; or riod of 7 or fewer consecutive days. A separate ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Impaired",
                            "RiskCategory": "H",
                            "AnnotationType": "positive",
                            "Characteristic": "Damage"
                        },
                        {
                            "type": "M",
                            "uuid": "a4d1dac4-8e4d-4afc-8e8f-ce77392f09f1",
                            "Answer": [
                                {
                                    "page": 50,
                                    "score": 1.0,
                                    "answer": "defamation, harassment, humiliation, dis-",
                                    "context": [
                                        "The following exclusion is added to Paragraph 2., Exclusions of Section I - Coverage A - Bodily Exclusions of Section I - Coverage B - Person- Injury And Property Damage Liability: al And Advertising Injury Liability: This insurance does not apply to: This insurance does not apply to: \"Bodily injury\" to: \"Personal and advertising injury\" to: (1) A person arising out of any: (1) A person arising out of any: (a) Refusal to employ that person; (a) Refusal to employ that person; (b) Termination of that person's employment; (b) Termination of that person's employment; or or (c) Employment-related practices, policies,"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.1614772230386734,
                                                "Y": 0.44932934641838074
                                            },
                                            {
                                                "X": 0.4801180958747864,
                                                "Y": 0.4493265450000763
                                            },
                                            {
                                                "X": 0.4801183342933655,
                                                "Y": 0.46129316091537476
                                            },
                                            {
                                                "X": 0.1614774614572525,
                                                "Y": 0.4612959921360016
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.4493265450000763,
                                            "Left": 0.1614772230386734,
                                            "Width": 0.31864112615585327,
                                            "Height": 0.01196946669369936
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "defamation, harassment, humiliation, dis- crimination or malicious prosecution di- crimination or malicious prosecution di- rected at that person; or rected at that person; or (2) The spouse, child, parent, brother or sister of (2) The spouse, child, parent, brother or sister of that person as a consequence of \"bodily injury\"",
                                        "prev": "\"Personal and advertising injury\" to: (1) A person arising out of any: (1) A person arising out of any: (a) Refusal to employ that person; (a) Refusal to employ that person; (b) Termination of that person's employment; (b) Termination of that person's employment; or or (c) Employment-related practices, policies, (c) Employment-related practices, policies, acts or omissions, such as coercion, demo- acts or omissions, such as coercion, demo- tion, evaluation, reassignment, discipline, tion, evaluation, reassignment, discipline, ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Defamation",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "f87b6ccb-17ee-4144-bb80-b36a0cb6f1ab",
                            "Answer": [
                                {
                                    "page": 50,
                                    "score": 1.0,
                                    "answer": "defamation, harassment, humiliation, dis-",
                                    "context": [
                                        "The following exclusion is added to Paragraph 2., Exclusions of Section I - Coverage A - Bodily Exclusions of Section I - Coverage B - Person- Injury And Property Damage Liability: al And Advertising Injury Liability: This insurance does not apply to: This insurance does not apply to: \"Bodily injury\" to: \"Personal and advertising injury\" to: (1) A person arising out of any: (1) A person arising out of any: (a) Refusal to employ that person; (a) Refusal to employ that person; (b) Termination of that person's employment; (b) Termination of that person's employment; or or (c) Employment-related practices, policies,"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5926069021224976,
                                                "Y": 0.4494299590587616
                                            },
                                            {
                                                "X": 0.9116146564483643,
                                                "Y": 0.44942712783813477
                                            },
                                            {
                                                "X": 0.9116148948669434,
                                                "Y": 0.4614395797252655
                                            },
                                            {
                                                "X": 0.5926071405410767,
                                                "Y": 0.4614424407482147
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.44942712783813477,
                                            "Left": 0.5926069021224976,
                                            "Width": 0.3190080225467682,
                                            "Height": 0.01201530173420906
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "crimination or malicious prosecution di- crimination or malicious prosecution di- rected at that person; or rected at that person; or (2) The spouse, child, parent, brother or sister of (2) The spouse, child, parent, brother or sister of that person as a consequence of \"bodily injury\" that person as a",
                                        "prev": "to: (1) A person arising out of any: (1) A person arising out of any: (a) Refusal to employ that person; (a) Refusal to employ that person; (b) Termination of that person's employment; (b) Termination of that person's employment; or or (c) Employment-related practices, policies, (c) Employment-related practices, policies, acts or omissions, such as coercion, demo- acts or omissions, such as coercion, demo- tion, evaluation, reassignment, discipline, tion, evaluation, reassignment, discipline, defamation, harassment, humiliation, dis- ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Defamation",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "b561f195-567d-4382-ba49-595c7617fbe3",
                            "Answer": [
                                {
                                    "page": 5,
                                    "score": 1.0,
                                    "answer": "Intellectual Property Amendment",
                                    "context": [
                                        "IL 00 17 11 98 Copyright, Insurance Services Office, Inc., 1998 Page 1 of 1 Class 1-91585 Risk POLICY NUMBER: U17PC30090-00 HPC 030 02 09 11 SCHEDULE OF FORMS AND ENDORSEMENTS The following are the forms attached to and forming a part of the policy at inception: Policy Jacket HPC 010 03 10 11 Common Policy Declarations USSIC IL 0017 11 98 Common Policy Conditions HPC 030 02 09 11 Scheduled Forms and Endorsement HPC 040 05 07 11 Named Insured HPC 040 18 03 13 New York Conditions CG 0163 07 11 New York Changes - Commercial General Liability"
                                    ],
                                    "is_true": "neutral",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.31097325682640076,
                                                "Y": 0.6357822418212891
                                            },
                                            {
                                                "X": 0.5360375046730042,
                                                "Y": 0.6357830762863159
                                            },
                                            {
                                                "X": 0.5360375642776489,
                                                "Y": 0.6476998925209045
                                            },
                                            {
                                                "X": 0.3109733462333679,
                                                "Y": 0.6476990580558777
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.6357822418212891,
                                            "Left": 0.31097325682640076,
                                            "Width": 0.22506432235240936,
                                            "Height": 0.011917673982679844
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "CG 2135 10 01 Exclusion - Coverage c - Medical Payments CG 2147 12 07 Employment-Related Practices Exclusion CG 2167 12 04 Fungi or Bacteria Exclusion CG 2186 12 04 Exclusion - Exterior Insulation And Finish Systems CG 2196 03 05 Silica or Silica-Related Dust Exclusion CG 2149 09 99",
                                        "prev": "Liability Coverage Part Supplemental Declarations CG 0001 12 07 Commercial General Liability Coverage Form - Occurrence HPC 040 04 11 11 Definition of Employee Amendment HPC 050 07 02 12 Exclusion Asbestos HPC 050 06 07 11 Exclusion Arsenic HPC 050 04 03 17 Exclusion - Cross Suits HPC 050 05 07 11 Exclusion - Operations Covered by a Consolidated (Wrap-Up) Insurance Program HPC 050 03 07 11 Exclusion Lead HPC 040 06 03 13 ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Intellectual Property",
                            "RiskCategory": "M",
                            "AnnotationType": "neutral",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "13d3289e-a5a7-40f6-b7dc-96a163fb2c87",
                            "Answer": [
                                {
                                    "page": 31,
                                    "score": 1.0,
                                    "answer": "mark, trade secret or other intellectual property",
                                    "context": [
                                        "mark, trade secret or other intellectual property 2."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.568560004234314,
                                                "Y": 0.6409303545951843
                                            },
                                            {
                                                "X": 0.9121367335319519,
                                                "Y": 0.6409304738044739
                                            },
                                            {
                                                "X": 0.9121366739273071,
                                                "Y": 0.6534398794174194
                                            },
                                            {
                                                "X": 0.568560004234314,
                                                "Y": 0.6534398198127747
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.6409303545951843,
                                            "Left": 0.568560004234314,
                                            "Width": 0.3435767590999603,
                                            "Height": 0.012509494088590145
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "2. Exclusions rights. Under this exclusion, such other intellec- tual property rights do not include the use of This insurance does not apply to: another's advertising idea in your \"advertise- a. Knowing Violation Of Rights Of Another ment\". \"Personal and advertising injury\" caused by or However, this exclusion does not",
                                        "prev": "provided for under Supplementary Pay- products or services stated in your \"advertise- ments - Coverages A and B. ment\". b. This insurance applies to \"personal and adver- i. Infringement Of Copyright, Patent, tising injury\" caused by an offense arising out Trademark Or Trade Secret of your business but only if the offense was \"Personal and advertising injury\" arising out of committed in the \"coverage territory\" during the the infringement of copyright, patent, trade- policy period. ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Intellectual Property",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "7b368cb7-7ada-47a9-a61d-42fc3f7d2a50",
                            "Answer": [
                                {
                                    "page": 48,
                                    "score": 1.0,
                                    "answer": "INTELLECTUAL PROPERTY AMENDMENT",
                                    "context": [
                                        "IL 00 17 11 98 Copyright, Insurance Services Office, Inc., 1998 Page 1 of 1 Class 1-91585 Risk POLICY NUMBER: U17PC30090-00 HPC 030 02 09 11 SCHEDULE OF FORMS AND ENDORSEMENTS The following are the forms attached to and forming a part of the policy at inception: Policy Jacket HPC 010 03 10 11 Common Policy Declarations USSIC IL 0017 11 98 Common Policy Conditions HPC 030 02 09 11 Scheduled Forms and Endorsement HPC 040 05 07 11 Named Insured HPC 040 18 03 13 New York Conditions CG 0163 07 11 New York Changes - Commercial General Liability"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.2045043408870697,
                                                "Y": 0.14494529366493225
                                            },
                                            {
                                                "X": 0.7952206134796143,
                                                "Y": 0.14494416117668152
                                            },
                                            {
                                                "X": 0.7952207326889038,
                                                "Y": 0.16262231767177582
                                            },
                                            {
                                                "X": 0.20450454950332642,
                                                "Y": 0.16262340545654297
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.14494416117668152,
                                            "Left": 0.2045043408870697,
                                            "Width": 0.5907163619995117,
                                            "Height": 0.017679238691926003
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "This endorsement modifies insurance provided under the following: COMMERCIAL GENERAL LIABILITY COVERAGE PART I. With respect to the coverage provided by this endorsement, Item 14. of SECTION V - DEF- i. Infringement of Copyright, Patent, Trade- INITIONS is deleted in its entirety and re- mark, Trade Secret, Trade Dress or",
                                        "prev": "\"lead\". to, existence of, or presence of \"lead\". C. The following definition is added to the Definitions Section: \"Lead\" means the element in any form. ALL OTHER TERMS AND CONDITIONS OF THIS POLICY REMAIN UNCHANGED HPC 050 03 07 11 Includes copyrighted material of Insurance Services Office, Inc., Page 1 of 1 Class 1-91585 Risk with its permission COMMERCIAL GENERAL LIABILITY HPC 040 06 03 13 THIS ENDORSEMENT CHANGES THE POLICY. PLEASE READ IT CAREFULLY. ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Intellectual Property",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "4e157f38-3a92-491b-9b78-55d54334b6da",
                            "Answer": [
                                {
                                    "page": 48,
                                    "score": 1.0,
                                    "answer": "(7) Any other intellectual property rights",
                                    "context": [
                                        "Under SECTION I - COVERAGES, COVER- (7) Any other intellectual property rights AGE B."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5930325388908386,
                                                "Y": 0.6085169911384583
                                            },
                                            {
                                                "X": 0.9110481142997742,
                                                "Y": 0.608517050743103
                                            },
                                            {
                                                "X": 0.911048173904419,
                                                "Y": 0.6214559078216553
                                            },
                                            {
                                                "X": 0.5930326581001282,
                                                "Y": 0.6214558482170105
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.6085169911384583,
                                            "Left": 0.5930325388908386,
                                            "Width": 0.3180156350135803,
                                            "Height": 0.012938971631228924
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "AGE B. PERSONAL AND ADVERTISING IN- recognized or implied by law; JURY LIABILITY, 2. EXCLUSIONS, exclusion i. Infringement of Copyright, Patent, b. False designation of the origin of a good, Trademark or Trade Secret, is deleted in its product or service. entirety and replaced with the following: ALL OTHER TERMS",
                                        "prev": "Trade secret; slanders or libels a person or organization or disparages a person's or organization's (5) Trade dress including without limitation, goods, products or services; or any shape, color, design or appearance used to distinguish the origin of a good, e. Oral or written publication of material that product or service; violates a person's right of privacy. (6) Advertising ideas, concepts, campaigns, or style of doing business; or II. Under SECTION I - COVERAGES, COVER- ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Intellectual Property",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "dc7d0df5-abe1-44cc-b510-5e62af135a24",
                            "Answer": [
                                {
                                    "page": 67,
                                    "score": 1.0,
                                    "answer": "(3) Scaffolding",
                                    "context": [
                                        "Commercial General Liability policies independent contractor performing work on which include: the designated project, you must provide to a) Limits of insurance of at least us copies of all insurance policies issued to $1,000,000 for Each Occurrence, at and contracts executed with all subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.14732974767684937,
                                                "Y": 0.5920984745025635
                                            },
                                            {
                                                "X": 0.2570417523384094,
                                                "Y": 0.5920981764793396
                                            },
                                            {
                                                "X": 0.2570418119430542,
                                                "Y": 0.6050050854682922
                                            },
                                            {
                                                "X": 0.14732982218265533,
                                                "Y": 0.6050053834915161
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.5920981764793396,
                                            "Left": 0.14732974767684937,
                                            "Width": 0.10971205681562424,
                                            "Height": 0.012907258234918118
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "contractor; (4) Crane or Hoist (mobile or fixed) c) Waiver of subrogation in favor of you (5) Elevators Construction and Permanent or equivalent blanket waiver of sub- (6) Concrete rogation wording for work performed by that subcontractor or independent (7) Masonry contractor; (8) Window Installation d) Full contractual liability coverage",
                                        "prev": "subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket additional in- (2) Excavation, Underpinning & Pile Driving sured wording for work performed by that subcontractor or independent ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Scaffolding",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "0abe08ce-e83e-4489-939c-a53442f487f4",
                            "Answer": [
                                {
                                    "page": 77,
                                    "score": 1.0,
                                    "answer": "(3) Scaffolding",
                                    "context": [
                                        "Commercial General Liability policies independent contractor performing work on which include: the designated project, you must provide to a) Limits of insurance of at least us copies of all insurance policies issued to $1,000,000 for Each Occurrence, at and contracts executed with all subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.14732974767684937,
                                                "Y": 0.5920984745025635
                                            },
                                            {
                                                "X": 0.2570417523384094,
                                                "Y": 0.5920981764793396
                                            },
                                            {
                                                "X": 0.2570418119430542,
                                                "Y": 0.6050050854682922
                                            },
                                            {
                                                "X": 0.14732982218265533,
                                                "Y": 0.6050053834915161
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.5920981764793396,
                                            "Left": 0.14732974767684937,
                                            "Width": 0.10971205681562424,
                                            "Height": 0.012907258234918118
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "contractor; (4) Crane or Hoist (mobile or fixed) c) Waiver of subrogation in favor of you (5) Elevators Construction and Permanent or equivalent blanket waiver of sub- (6) Concrete rogation wording for work performed by that subcontractor or independent (7) Masonry contractor; (8) Window Installation d) Full contractual liability coverage",
                                        "prev": "subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket additional in- (2) Excavation, Underpinning & Pile Driving sured wording for work performed by that subcontractor or independent ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Scaffolding",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "a1d43f0e-e2dc-49da-bd33-02dee593cc8e",
                            "Answer": [
                                {
                                    "page": 80,
                                    "score": 1.0,
                                    "answer": "(3) Scaffolding",
                                    "context": [
                                        "Commercial General Liability policies independent contractor performing work on which include: the designated project, you must provide to a) Limits of insurance of at least us copies of all insurance policies issued to $1,000,000 for Each Occurrence, at and contracts executed with all subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket"
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.14732974767684937,
                                                "Y": 0.5920984745025635
                                            },
                                            {
                                                "X": 0.2570417523384094,
                                                "Y": 0.5920981764793396
                                            },
                                            {
                                                "X": 0.2570418119430542,
                                                "Y": 0.6050050854682922
                                            },
                                            {
                                                "X": 0.14732982218265533,
                                                "Y": 0.6050053834915161
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.5920981764793396,
                                            "Left": 0.14732974767684937,
                                            "Width": 0.10971205681562424,
                                            "Height": 0.012907258234918118
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "contractor; (4) Crane or Hoist (mobile or fixed) c) Waiver of subrogation in favor of you (5) Elevators Construction and Permanent or equivalent blanket waiver of sub- (6) Concrete rogation wording for work performed by that subcontractor or independent (7) Masonry contractor; (8) Window Installation d) Full contractual liability coverage",
                                        "prev": "subcontrac- least $2,000,000 for the General Ag- tors or independent contractors performing gregate, and at least $2,000,000 for any of the following types of work on your be- the Products-Completed Operations half at the designated project listed on the Aggregate; policy: b) An additional insured endorsement naming you as an additional insured (1) Demolition or equivalent blanket additional in- (2) Excavation, Underpinning & Pile Driving sured wording for work performed by that subcontractor or independent ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Scaffolding",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Liability"
                        },
                        {
                            "type": "M",
                            "uuid": "067bc24d-b6ff-4f43-aed7-769c668ea977",
                            "Answer": [
                                {
                                    "page": 10,
                                    "score": 1.0,
                                    "answer": "recover on an agreed settlement or on a",
                                    "context": [
                                        "becomes legally obligated to pay as A person or organization may sue us to damages because of \"personal and recover on an agreed settlement or on a advertising injury\" to which this insurance final judgment against an insured; but we applies."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5937067866325378,
                                                "Y": 0.3091389536857605
                                            },
                                            {
                                                "X": 0.9114511013031006,
                                                "Y": 0.30913853645324707
                                            },
                                            {
                                                "X": 0.9114510416984558,
                                                "Y": 0.3214859068393707
                                            },
                                            {
                                                "X": 0.5937067270278931,
                                                "Y": 0.32148632407188416
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.30913853645324707,
                                            "Left": 0.5937067270278931,
                                            "Width": 0.3177443742752075,
                                            "Height": 0.012347795069217682
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "advertising injury\" to which this insurance final judgment against an insured; but we applies. We will have the right and duty to will not be liable for damages that are not defend the insured against any \"suit\" payable under the terms of this Coverage seeking those damages even if the",
                                        "prev": "Section I - Coverage B us into a \"suit\" asking for damages from Personal And Advertising Injury Liability is an insured; or replaced by the following: (2) To sue us on this Coverage Part unless 1. Insuring Agreement all of its terms have been fully complied a. We will pay those sums that the insured with. becomes legally obligated to pay as A person or organization may sue us to damages because of \"personal and ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "2a87cd47-0390-4672-af9b-5de5999d89fe",
                            "Answer": [
                                {
                                    "page": 10,
                                    "score": 1.0,
                                    "answer": "limit of insurance. An agreed settlement",
                                    "context": [
                                        "becomes legally obligated to pay as A person or organization may sue us to damages because of \"personal and recover on an agreed settlement or on a advertising injury\" to which this insurance final judgment against an insured; but we applies."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5934309959411621,
                                                "Y": 0.37819793820381165
                                            },
                                            {
                                                "X": 0.9122170209884644,
                                                "Y": 0.3781976103782654
                                            },
                                            {
                                                "X": 0.9122169613838196,
                                                "Y": 0.3909526765346527
                                            },
                                            {
                                                "X": 0.5934309363365173,
                                                "Y": 0.3909529745578766
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3781976103782654,
                                            "Left": 0.5934309363365173,
                                            "Width": 0.31878605484962463,
                                            "Height": 0.012755355797708035
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "false or fraudulent. However, we will have means a settlement and release of liability no duty to defend the insured against any signed by us, the insured and the claimant \"suit\" seeking damages for \"personal and or the claimant's legal representative. advertising injury\" to which this insurance does not apply.",
                                        "prev": "\"personal and recover on an agreed settlement or on a advertising injury\" to which this insurance final judgment against an insured; but we applies. We will have the right and duty to will not be liable for damages that are not defend the insured against any \"suit\" payable under the terms of this Coverage seeking those damages even if the Part or that are in excess of the applicable allegations of the \"suit\" are groundless, ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "f235761c-1c11-48d8-ad26-b616de4853c4",
                            "Answer": [
                                {
                                    "page": 10,
                                    "score": 1.0,
                                    "answer": "means a settlement and release of liability",
                                    "context": [
                                        "However, we will have means a settlement and release of liability no duty to defend the insured against any signed by us, the insured and the claimant \"suit\" seeking damages for \"personal and or the claimant's legal representative."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.5938094854354858,
                                                "Y": 0.392203688621521
                                            },
                                            {
                                                "X": 0.9120352864265442,
                                                "Y": 0.3922033905982971
                                            },
                                            {
                                                "X": 0.9120352268218994,
                                                "Y": 0.40498411655426025
                                            },
                                            {
                                                "X": 0.5938094258308411,
                                                "Y": 0.40498438477516174
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.3922033905982971,
                                            "Left": 0.5938094258308411,
                                            "Width": 0.31822583079338074,
                                            "Height": 0.012781016528606415
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "no duty to defend the insured against any signed by us, the insured and the claimant \"suit\" seeking damages for \"personal and or the claimant's legal representative. advertising injury\" to which this insurance does not apply. We may, at our discretion, b. With respect to \"bodily injury\" and \"personal investigate",
                                        "prev": "which this insurance final judgment against an insured; but we applies. We will have the right and duty to will not be liable for damages that are not defend the insured against any \"suit\" payable under the terms of this Coverage seeking those damages even if the Part or that are in excess of the applicable allegations of the \"suit\" are groundless, limit of insurance. An agreed settlement false or fraudulent. However, we will have ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "3b449215-5710-473f-bdcc-308727f23e85",
                            "Answer": [
                                {
                                    "page": 36,
                                    "score": 1.0,
                                    "answer": "plicable limit of insurance. An agreed settlement",
                                    "context": [
                                        "becomes legally obligated to pay as A person or organization may sue us to damages because of \"personal and recover on an agreed settlement or on a advertising injury\" to which this insurance final judgment against an insured; but we applies."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11266332864761353,
                                                "Y": 0.7481685280799866
                                            },
                                            {
                                                "X": 0.48099538683891296,
                                                "Y": 0.7481698393821716
                                            },
                                            {
                                                "X": 0.4809953272342682,
                                                "Y": 0.7610698938369751
                                            },
                                            {
                                                "X": 0.11266330629587173,
                                                "Y": 0.7610685229301453
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7481685280799866,
                                            "Left": 0.11266330629587173,
                                            "Width": 0.3683320879936218,
                                            "Height": 0.012901373207569122
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "(2) When this insurance is excess, we will have means a settlement and release of liability signed no duty under Coverages A or B to defend by us, the insured and the claimant or the claim- the insured against any \"suit\" if any other ant's legal representative. insurer has a",
                                        "prev": "person or organization may sue us to recover on ing out of the premises or operations, or an agreed settlement or on a final judgment the products and completed operations, against an insured; but we will not be liable for for which you have been added as an damages that are not payable under the terms of additional insured by attachment of an endorsement. this Coverage Part or that are in excess of the ap- ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "da8c01e6-17a1-4d12-a967-87e683f8e7a2",
                            "Answer": [
                                {
                                    "page": 36,
                                    "score": 1.0,
                                    "answer": "means a settlement and release of liability signed",
                                    "context": [
                                        "An agreed settlement (2) When this insurance is excess, we will have means a settlement and release of liability signed no duty under Coverages A or B to defend by us, the insured and the claimant or the claim- the insured against any \"suit\" if any other ant's legal representative."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11296017467975616,
                                                "Y": 0.7621781826019287
                                            },
                                            {
                                                "X": 0.4802290201187134,
                                                "Y": 0.7621795535087585
                                            },
                                            {
                                                "X": 0.4802289605140686,
                                                "Y": 0.7750470042228699
                                            },
                                            {
                                                "X": 0.11296015232801437,
                                                "Y": 0.77504563331604
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.7621781826019287,
                                            "Left": 0.11296015232801437,
                                            "Width": 0.3672688901424408,
                                            "Height": 0.012868830934166908
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "no duty under Coverages A or B to defend by us, the insured and the claimant or the claim- the insured against any \"suit\" if any other ant's legal representative. insurer has a duty to defend the insured against that \"suit\". If no other insurer de- fends, we will undertake",
                                        "prev": "or an agreed settlement or on a final judgment the products and completed operations, against an insured; but we will not be liable for for which you have been added as an damages that are not payable under the terms of additional insured by attachment of an endorsement. this Coverage Part or that are in excess of the ap- plicable limit of insurance. An agreed settlement (2) When this insurance is excess, we will have ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        },
                        {
                            "type": "M",
                            "uuid": "43bb45b3-200b-4044-80ee-8387a3c59027",
                            "Answer": [
                                {
                                    "page": 38,
                                    "score": 1.0,
                                    "answer": "settlement we agree to.",
                                    "context": [
                                        "territory described in Paragraph a. above or in a settlement we agree to."
                                    ],
                                    "is_true": "positive",
                                    "geometry": {
                                        "Polygon": [
                                            {
                                                "X": 0.11280083656311035,
                                                "Y": 0.49093860387802124
                                            },
                                            {
                                                "X": 0.28174713253974915,
                                                "Y": 0.4909381568431854
                                            },
                                            {
                                                "X": 0.28174716234207153,
                                                "Y": 0.5036193132400513
                                            },
                                            {
                                                "X": 0.11280088871717453,
                                                "Y": 0.5036197304725647
                                            }
                                        ],
                                        "BoundingBox": {
                                            "Top": 0.4909381568431854,
                                            "Left": 0.11280083656311035,
                                            "Width": 0.1689463108778,
                                            "Height": 0.012681578285992146
                                        }
                                    },
                                    "context_tokens": {
                                        "next": "Paragraph f. does not include that part of any contract or agreement: 5. \"Employee\" includes a \"leased worker\". \"Employ- ee\" does not include a \"temporary worker\". (1) That indemnifies a railroad for \"bodily injury\" or \"property damage\" arising out of con- 6. \"Executive officer\" means a person holding any of",
                                        "prev": "another that take place through the Internet or simi- party to pay for \"bodily injury\" or \"property lar electronic means of communication damage\" to a third person or organization. Tort liability means a liability that would be imposed provided the insured's responsibility to pay dam- by law in the absence of any contract or ages is determined in a \"suit\" on the merits, in the agreement. territory described in Paragraph a. above or in a ",
                                        "next_count": 50,
                                        "prev_count": 75
                                    }
                                }
                            ],
                            "Question": "Settlement",
                            "RiskCategory": "M",
                            "AnnotationType": "positive",
                            "Characteristic": "Other"
                        }
                    ]
                }
            }
        }
    ]

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go

# -----------------------------
# INPUT DATA
# -----------------------------
data = results  # replace this

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}

# Define buckets
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

# Assign dates
for doc in data:
    risk = doc["risk_info"]["document_risk_score"]
    start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["upload_date"] = random_date(start, end)

# Sort by upload date
docs = sorted(data, key=lambda x: x["upload_date"])

# -----------------------------
# STEP 2: BUILD TIMELINE
# -----------------------------
dates = []
risks = []
colors = []
hover_texts = []

current_max_risk = 0

for doc in docs:
    date = doc["upload_date"]
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    # Extract annotations
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    category_map = {}
    keywords = []

    for a in ann:
        category = a.get("Characteristic", "Other")
        keyword = a.get("Question", "Unknown")

        keywords.append(keyword)

        if category not in category_map:
            category_map[category] = []
        category_map[category].append(keyword)

    # Check risk increase
    if doc_risk > current_max_risk:
        current_max_risk = doc_risk
        trigger_flag = True
    else:
        trigger_flag = False

    # Build hover text (rich UI)
    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Date: {date.strftime('%Y-%m-%d')}<br>"
    hover += f"Claim Risk: {risk_label[current_max_risk]}<br>"

    if trigger_flag:
        hover += "<br><b>Risk Increased Due To:</b><br>"
    else:
        hover += "<br><b>Observed Keywords:</b><br>"

    for cat, kws in category_map.items():
        hover += f"<b>{cat}</b>: {', '.join(set(kws))}<br>"

    dates.append(date)
    risks.append(current_max_risk)
    colors.append(risk_color[current_max_risk])
    hover_texts.append(hover)

# -----------------------------
# STEP 3: CREATE INTERACTIVE PLOT
# -----------------------------
fig = go.Figure()

# Line + markers
fig.add_trace(go.Scatter(
    x=dates,
    y=risks,
    mode='lines+markers',
    marker=dict(size=10, color=colors),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# STEP 4: BACKGROUND RISK ZONES
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0.5, y1=1.5,
              fillcolor="green", opacity=0.1, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=1.5, y1=2.5,
              fillcolor="orange", opacity=0.1, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=2.5, y1=3.5,
              fillcolor="red", opacity=0.1, layer="below", line_width=0)

# -----------------------------
# STEP 5: FINAL FORMATTING
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",
    xaxis_title="Document Upload Date",
    yaxis_title="Claim Risk",
    yaxis=dict(
        tickvals=[1, 2, 3],
        ticktext=["Low", "Moderate", "High"],
        range=[0.8, 3.2]
    ),
    hoverlabel=dict(bgcolor="white", font_size=12),
    template="plotly_white",
    height=600
)

fig.show()

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go

# -----------------------------
# INPUT DATA
# -----------------------------
data = results

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

# -----------------------------
# STEP 1: ASSIGN RISK-AWARE DATES (for display only)
# -----------------------------
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

for doc in data:
    risk = doc["risk_info"]["document_risk_score"]
    start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["display_date"] = random_date(start, end)

# Sort by risk → ensures clean progression
docs = sorted(data, key=lambda x: x["display_date"])

# -----------------------------
# STEP 2: BUILD TIMELINE (INDEX-BASED X)
# -----------------------------
x_vals = list(range(len(docs)))  # evenly spaced
y_vals = []
colors = []
hover_texts = []

current_max_risk = 0
seen_keywords = set()

for i, doc in enumerate(docs):
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    category_map = {}
    current_keywords = set()

    for a in ann:
        category = a.get("Characteristic", "Other")
        keyword = a.get("Question", "Unknown")

        current_keywords.add((category, keyword))

        if category not in category_map:
            category_map[category] = []
        category_map[category].append(keyword)

    # Detect new keywords
    new_keywords = current_keywords - seen_keywords

    # Risk logic
    risk_increased = doc_risk > current_max_risk
    same_risk = doc_risk == current_max_risk

    if risk_increased:
        current_max_risk = doc_risk

    seen_keywords.update(current_keywords)

    # -----------------------------
    # HOVER TEXT BUILDING
    # -----------------------------
    color = risk_color[current_max_risk]

    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Date: {doc['display_date'].strftime('%Y-%m-%d')}<br>"
    hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span><br><br>"

    # CASE 1: Risk increased
    if risk_increased:
        if new_keywords:
            hover += f"<b>New {risk_label[current_max_risk]} Risk Signals:</b><br>"
        else:
            hover += f"<b>No new {risk_label[current_max_risk]} risk signals found</b><br>"

    # CASE 2: Same risk
    elif same_risk:
        if new_keywords:
            hover += f"<b>New {risk_label[current_max_risk]} Signals Observed:</b><br>"
        else:
            hover += f"<b>No new {risk_label[current_max_risk]} risk signals found</b><br>"

    # Add category-wise breakdown ONLY for new keywords
    if new_keywords:
        temp_map = {}
        for cat, kw in new_keywords:
            if cat not in temp_map:
                temp_map[cat] = []
            temp_map[cat].append(kw)

        for cat, kws in temp_map.items():
            hover += f"<span style='color:black'><b>{cat}</b></span>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"

    y_vals.append(current_max_risk)
    colors.append(color)
    hover_texts.append(hover)

# -----------------------------
# STEP 3: PLOT
# -----------------------------
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    marker=dict(size=10, color=colors),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# STEP 4: BACKGROUND RISK ZONES
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0.5, y1=1.5,
              fillcolor="green", opacity=0.1, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=1.5, y1=2.5,
              fillcolor="orange", opacity=0.1, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=2.5, y1=3.5,
              fillcolor="red", opacity=0.1, layer="below", line_width=0)

# -----------------------------
# STEP 5: FORMAT
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",
    xaxis=dict(
        title="Document Sequence (by Date)",
        tickvals=x_vals,
        ticktext=[doc["display_date"].strftime("%b %d") for doc in docs]
    ),
    yaxis=dict(
        title="Claim Risk",
        tickvals=[1, 2, 3],
        ticktext=["Low", "Moderate", "High"],
        range=[0.8, 3.2]
    ),
    template="plotly_white",
    height=600,

    # ✅ FIXED HOVER STYLE
    hoverlabel=dict(
        bgcolor="white",      # force white background
        font_size=13,
        font_family="Arial",
        font_color="black",   # base text color
        bordercolor="lightgrey",
        align="left"
    )
)

fig.show()

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go

# -----------------------------
# INPUT DATA
# -----------------------------
data = results

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

# -----------------------------
# STEP 1: ASSIGN DATES (RISK-AWARE)
# -----------------------------
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

for doc in data:
    risk = doc["risk_info"]["document_risk_score"]
    start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["display_date"] = random_date(start, end)

# Sort by date
docs = sorted(data, key=lambda x: x["display_date"])

# -----------------------------
# STEP 2: BUILD TIMELINE
# -----------------------------
x_vals = list(range(len(docs)))

# Segmented Y-axis base
risk_base = {1: 0, 2: 100, 3: 200}

# Track cumulative signals per risk level
cumulative_by_risk = {1: 0, 2: 0, 3: 0}

y_vals = []
colors = []
hover_texts = []

current_max_risk = 0
seen_keywords = set()

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = set()

    for a in ann:
        category = a.get("Characteristic", "Other")
        keyword = a.get("Question", "Unknown")
        current_keywords.add((category, keyword))

    # New keywords
    new_keywords = current_keywords - seen_keywords

    # Update risk
    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    # Filter only relevant signals for current risk
    relevant_new_keywords = set()

    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                keyword_risk = risk_map.get(a.get("RiskCategory"), 0)
                if keyword_risk == current_max_risk:
                    relevant_new_keywords.add((cat, kw))

    # Update cumulative count
    cumulative_by_risk[current_max_risk] += len(relevant_new_keywords)

    seen_keywords.update(current_keywords)

    # Compute Y value (segmented)
    y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk]

    # -----------------------------
    # HOVER TEXT
    # -----------------------------
    color = risk_color[current_max_risk]

    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Date: {doc['display_date'].strftime('%Y-%m-%d')}<br>"
    hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span><br>"
    hover += f"Cumulative Signals: <b>{cumulative_by_risk[current_max_risk]}</b><br><br>"

    if relevant_new_keywords:
        hover += "<b>New Signals:</b><br>"
        temp_map = {}
        for cat, kw in relevant_new_keywords:
            temp_map.setdefault(cat, []).append(kw)

        for cat, kws in temp_map.items():
            hover += f"<span style='color:{color}'><b>{cat}</b>: {', '.join(set(kws))}</span><br>"
    else:
        if doc_risk > current_max_risk:
            hover += "<b>No risk signals found increasing the risk</b><br>"
        else:
            hover += "<b>No risk signals found</b><br>"

    y_vals.append(y_val)
    colors.append(color)
    hover_texts.append(hover)

# -----------------------------
# STEP 3: PLOT
# -----------------------------
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    marker=dict(
        size=12,   # bigger markers for visibility
        color=colors,
        line=dict(width=1, color='black')
    ),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# STEP 4: BACKGROUND REGIONS
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0, y1=100,
              fillcolor="green", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=100, y1=200,
              fillcolor="orange", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=200, y1=300,
              fillcolor="red", opacity=0.08, layer="below", line_width=0)

# -----------------------------
# STEP 5: FINAL LAYOUT
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",
    
    xaxis=dict(
        title="Document Sequence",
        tickvals=x_vals,
        ticktext=[doc["display_date"].strftime("%b %d") for doc in docs]
    ),

    yaxis=dict(
        title="Risk Signal Progression",
        tickvals=[50, 150, 250],
        ticktext=["Low Risk", "Moderate Risk", "High Risk"],
        range=[0, 300]
    ),

    template="plotly_white",

    height=700,   # increased height → FIXES compression
    width=1200,   # increased width → FIXES overlap

    hoverlabel=dict(
        bgcolor="white",
        font_size=13,
        font_family="Arial",
        font_color="black",
        bordercolor="lightgrey",
        align="left"
    )
)

fig.show()

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go

# -----------------------------
# INPUT DATA
# -----------------------------
data = results

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

MIN_OFFSET = 1     # ensures point not on boundary
PADDING = 2        # space above max

# -----------------------------
# STEP 1: ASSIGN DATES
# -----------------------------
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

for doc in data:
    risk = doc["risk_info"]["document_risk_score"]
    start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["display_date"] = random_date(start, end)

data[-1]["display_date"] = data[-2]["display_date"]

docs = sorted(data, key=lambda x: x["display_date"])
docs[-1]["display_date"] = docs[-2]["display_date"]
# -----------------------------
# STEP 2: FIRST PASS → get max signals per region
# -----------------------------
seen_keywords = set()
current_max_risk = 0

cumulative_by_risk = {1: 0, 2: 0, 3: 0}
max_by_risk = {1: 0, 2: 0, 3: 0}

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = set()
    for a in ann:
        current_keywords.add((a.get("Characteristic"), a.get("Question")))

    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)
    max_by_risk[current_max_risk] = max(
        max_by_risk[current_max_risk],
        cumulative_by_risk[current_max_risk]
    )

    seen_keywords.update(current_keywords)

# -----------------------------
# STEP 3: DEFINE REGION BASES (DYNAMIC)
# -----------------------------
low_height = max_by_risk[1] + PADDING + MIN_OFFSET
mod_height = max_by_risk[2] + PADDING + MIN_OFFSET
high_height = max_by_risk[3] + PADDING + MIN_OFFSET

risk_base = {
    1: 0,
    2: low_height,
    3: low_height + mod_height
}

total_height = low_height + mod_height + high_height

# -----------------------------
# STEP 4: SECOND PASS → build plot data
# -----------------------------
x_vals = list(range(len(docs)))

y_vals = []
colors = []
hover_texts = []

seen_keywords = set()
current_max_risk = 0
cumulative_by_risk = {1: 0, 2: 0, 3: 0}

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)

    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = set()
    for a in ann:
        current_keywords.add((a.get("Characteristic"), a.get("Question")))

    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)

    seen_keywords.update(current_keywords)

    # FINAL Y VALUE (with offset)
    y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk] + MIN_OFFSET

    # -----------------------------
    # HOVER
    # -----------------------------
    color = risk_color[current_max_risk]

    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Date: {doc['display_date'].strftime('%Y-%m-%d')}<br>"
    hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span><br>"
    hover += f"Cumulative Signals: <b>{cumulative_by_risk[current_max_risk]}</b><br><br>"

    if relevant:
        hover += f"<b>New {risk_label[current_max_risk]} Risk Signals: {(len(relevant))}</b><br>"
        temp = {}
        for cat, kw in relevant:
            temp.setdefault(cat, []).append(kw)

        for cat, kws in temp.items():
            hover += f"<span style='color:black'><b>{cat}</b></span>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"
    else:
        hover += f"<b>No new {risk_label[current_max_risk]} risk signals found</b><br>"

    y_vals.append(y_val)
    colors.append(color)
    hover_texts.append(hover)

# -----------------------------
# STEP 5: PLOT
# -----------------------------
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    marker=dict(size=12, color=colors, line=dict(width=1, color='black')),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# BACKGROUND REGIONS (DYNAMIC)
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0, y1=low_height,
              fillcolor="green", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height, y1=low_height+mod_height,
              fillcolor="orange", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height+mod_height, y1=total_height,
              fillcolor="red", opacity=0.08, layer="below", line_width=0)

# -----------------------------
# FINAL LAYOUT
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",

    xaxis=dict(
        title="Document Arrival (by Date)",
        tickvals=x_vals,
        ticktext=[doc["display_date"].strftime("%b %d") for doc in docs]
    ),

    yaxis=dict(
        title="Claim Risk",
        tickvals=[
            low_height / 2,
            low_height + mod_height / 2,
            low_height + mod_height + high_height / 2
        ],
        ticktext=["Low Risk", "Moderate Risk", "High Risk"],
        range=[0, total_height]
    ),

    template="plotly_white",
    height=700,
    width=1200,

    hoverlabel=dict(
        bgcolor="white",
        font_size=13,
        font_family="Arial",
        font_color="black",
        bordercolor="lightgrey",
        align="left"
    )
)

fig.show()

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go
from collections import defaultdict

# -----------------------------
# INPUT DATA
# -----------------------------
data = results

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

MIN_OFFSET = 1
PADDING = 2

# -----------------------------
# STEP 1: ASSIGN DATES
# -----------------------------
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

for doc in data:
    risk = doc["risk_info"]["document_risk_score"]
    start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["display_date"] = random_date(start, end)

docs = sorted(data, key=lambda x: x["display_date"])
# docs[-1]["display_date"] = docs[-2]["display_date"]
# -----------------------------
# STEP 2: FIRST PASS (same)
# -----------------------------
seen_keywords = set()
current_max_risk = 0

cumulative_by_risk = {1: 0, 2: 0, 3: 0}
max_by_risk = {1: 0, 2: 0, 3: 0}

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)
    max_by_risk[current_max_risk] = max(
        max_by_risk[current_max_risk],
        cumulative_by_risk[current_max_risk]
    )

    seen_keywords.update(current_keywords)

# -----------------------------
# STEP 3: REGION HEIGHTS
# -----------------------------
low_height = max_by_risk[1] + PADDING + MIN_OFFSET
mod_height = max_by_risk[2] + PADDING + MIN_OFFSET
high_height = max_by_risk[3] + PADDING + MIN_OFFSET

risk_base = {
    1: 0,
    2: low_height,
    3: low_height + mod_height
}

total_height = low_height + mod_height + high_height

# -----------------------------
# STEP 4: SECOND PASS + GROUPING
# -----------------------------
seen_keywords = set()
current_max_risk = 0
cumulative_by_risk = {1: 0, 2: 0, 3: 0}

grouped = defaultdict(list)

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)
    seen_keywords.update(current_keywords)

    y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk] + MIN_OFFSET
    color = risk_color[current_max_risk]

    # -----------------------------
    # BUILD PER-DOC HOVER
    # -----------------------------
    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span><br>"
    hover += f"Cumulative Signals: <b>{cumulative_by_risk[current_max_risk]}</b><br>"

    if relevant:
        hover += f"<b>New {risk_label[current_max_risk]} Risk Signals: ({len(relevant)})</b><br>"
        temp = {}
        for cat, kw in relevant:
            temp.setdefault(cat, []).append(kw)

        for cat, kws in temp.items():
            hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"
    else:
        hover += f"<b>No new {risk_label[current_max_risk]} signals</b><br>"

    hover += "<br>"

    grouped[doc["display_date"]].append({
        "hover": hover,
        "y": y_val,
        "color": color
    })

# -----------------------------
# STEP 5: BUILD FINAL PLOT DATA
# -----------------------------
x_vals = []
y_vals = []
colors = []
hover_texts = []

sorted_dates = sorted(grouped.keys())

for i, date in enumerate(sorted_dates):
    entries = grouped[date]

    combined_hover = f"<b>Date: {date.strftime('%Y-%m-%d')}</b><br><br>"
    combined_hover += "".join([e["hover"] for e in entries])

    # take last state (latest doc that day)
    y_val = entries[-1]["y"]
    color = entries[-1]["color"]

    x_vals.append(i)
    y_vals.append(y_val)
    colors.append(color)
    hover_texts.append(combined_hover)

# -----------------------------
# STEP 6: PLOT
# -----------------------------
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    marker=dict(size=12, color=colors, line=dict(width=1, color='black')),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# BACKGROUND REGIONS
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0, y1=low_height,
              fillcolor="green", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height, y1=low_height+mod_height,
              fillcolor="orange", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height+mod_height, y1=total_height,
              fillcolor="red", opacity=0.08, layer="below", line_width=0)

# -----------------------------
# FINAL LAYOUT
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",

    xaxis=dict(
        title="Date Document Recieved (Grouped by Date)",
        tickvals=x_vals,
        ticktext=[d.strftime("%b %d") for d in sorted_dates]
    ),

    yaxis=dict(
        title="Claim Risk",
        tickvals=[
            low_height / 2,
            low_height + mod_height / 2,
            low_height + mod_height + high_height / 2
        ],
        ticktext=["Low Risk", "Moderate Risk", "High Risk"],
        range=[0, total_height]
    ),

    template="plotly_white",
    height=700,
    width=1200,

    hoverlabel=dict(
        bgcolor="white",
        font_size=13,
        font_family="Arial",
        font_color="black",
        bordercolor="lightgrey",
        align="left"
    )
)

fig.show()

# %% [markdown]
# ### Empro Claim File 138226

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9...._.5Ua-yDPgBDCVhsxdxTfzkY7B96qYTDPugGvO5lyBpqwgKrGuna5MwETfG9_1NGYDfZONlVZIgR78aMs2Bh9_wbPDsZsnxojLSNa8fBl4rWsNmef3sVpxmGgly7V0mhHK5LPLcgvQuSPaQtzJPaSPiPlWZkiXjrHqJFedNyHiwsSvmnjLFDrH-_PqjV5MAGBJ3SKl-xMeAIQKbvhijgWNLXER8KKM4Lsr2QAgrQiy89JOuHHBy_hmbxAzfXDbx0-nwMsTwEhjIFd1SYsy3_ErnMoO3wCuk8Mp_mFi89xikeLuGFzbgE7C4loIX1VWWRFxRv_HaSbWfzpmXVyfIeih2A"
search_api_url = lambda i: f"https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/16/docs/?annotations=true&limit=5&offset={i}"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
final_results = []
next_api = search_api_url(0)
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
count = response_json["count"]
for i in range(0,count,5):
    response = requests.get(
                search_api_url(i),  # Replace with actual API endpoint
                headers=headers,
            )
    if not response:
        break
    response_json = response.json()
    final_results.extend(response_json["results"])

# %%
len(final_results)
# Out:
# 70

# %%
final_results
# Out:
# [{'id': 5996,
#   'uuid': 'bea29635-dcdf-4576-9fc9-b7146d4fe316',
#   'claim_file': 16,
#   'created_at': '2026-04-07T21:19:04.391736+05:30',
#   'updated_at': '2026-04-10T14:31:44.973900+05:30',
#   'metadata': {},
#   'name': '138226.pdf',
#   'state': 'annotated',
#   'risk_info': {'document_risk_score': 'L'},
#   'pdf_file': 'https://dbmi3mqa42l1z.cloudfront.net/bea29635-dcdf-4576-9fc9-b7146d4fe316__document_uuid__138226.pdf?Expires=1775815740&Signature=Q7NyjrP7WfrVDXBp4ujQUGWE3ZgCdV45TsmSqjJ-wRG-JouwefBvMfcLeB042fQ8IQ~Y-7kMiF6Y8jvRCFlTiJRCWlAOG~G1EL8u2w7FJk5z1otDRj9Az2ABoXA5sOmLsiLYZP0LW9B3dJIcc~caDLKFgCY2dqSnYumRJ4H-Dzsx~H1Q~T8DSc5k1~r-GcPRLcyesxSWkHT~AwZV4stn9tygRlvgqG8n2VYWqWey6r1hohSQBDSZKjH~CYoI8IlF1Ivi8a30~Of20MBxfUzULWDrTpwuNHLE0I05lJZckBmVIFewzfLUCnUBcT5fpQy9BrSxjY57S7E2AenGTuJHPg__&Key-Pair-Id=K243EB1Y77S53T',
#   'document_type': 'Policy Declaration Report',
#   'raw_content_type': 'application/pdf',
#   'overall_state': 'completed',
# ...

# %%
import pickle

with open("risk-report-timeline-results-138226.pkl", "wb") as f:
    pickle.dump(final_results, f)

# %%
import random
from datetime import datetime, timedelta
import plotly.graph_objects as go
from collections import defaultdict
import re 
from datetime import datetime

# -----------------------------
# INPUT DATA
# -----------------------------
data = final_results

# -----------------------------
# CONFIG
# -----------------------------
risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

MIN_OFFSET = 1
PADDING = 2

# -----------------------------
# STEP 1: ASSIGN DATES
# -----------------------------
date_buckets = {
    "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
    "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
    "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
}

def random_date(start, end):
    delta = end - start
    return start + timedelta(days=random.randint(0, delta.days))

def get_date(doc):
    """
    Extracts date from doc['name'] after 'Doc Date'.
    Falls back to created_at.
    Returns timezone-naive datetime (safe for sorting).
    """

    name = doc.get("name", "")

    # Extract Doc Date
    match = re.search(r"Doc Date\s*(\d{1,2}-\d{1,2}-\d{2,4})", name)

    if match:
        date_str = match.group(1)

        for fmt in ("%d-%m-%Y", "%d-%m-%y"):
            try:
                dt = datetime.strptime(date_str, fmt)
                return dt  # already naive
            except ValueError:
                continue

    # Fallback → created_at
    created_at = doc.get("created_at")

    if created_at:
        try:
            dt = datetime.fromisoformat(created_at)

            # ✅ Convert to naive datetime
            if dt.tzinfo is not None:
                dt = dt.replace(tzinfo=None)

            return dt
        except Exception:
            pass

    # Final fallback
    return datetime.now()

for doc in data:
    # risk = doc["risk_info"]["document_risk_score"]
    # start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
    doc["display_date"] = get_date(doc)

docs = sorted(data, key=lambda x: x["display_date"])
# docs[-1]["display_date"] = docs[-2]["display_date"]
# -----------------------------
# STEP 2: FIRST PASS (same)
# -----------------------------
seen_keywords = set()
current_max_risk = 0

cumulative_by_risk = {1: 0, 2: 0, 3: 0}
max_by_risk = {1: 0, 2: 0, 3: 0}

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)
    max_by_risk[current_max_risk] = max(
        max_by_risk[current_max_risk],
        cumulative_by_risk[current_max_risk]
    )

    seen_keywords.update(current_keywords)

# -----------------------------
# STEP 3: REGION HEIGHTS
# -----------------------------
low_height = max_by_risk[1] + PADDING + MIN_OFFSET
mod_height = max_by_risk[2] + PADDING + MIN_OFFSET
high_height = max_by_risk[3] + PADDING + MIN_OFFSET

risk_base = {
    1: 0,
    2: low_height,
    3: low_height + mod_height
}

total_height = low_height + mod_height + high_height

# -----------------------------
# STEP 4: SECOND PASS + GROUPING
# -----------------------------
seen_keywords = set()
current_max_risk = 0
cumulative_by_risk = {1: 0, 2: 0, 3: 0}

grouped = defaultdict(list)

for doc in docs:
    doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
    ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

    current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
    new_keywords = current_keywords - seen_keywords

    if doc_risk > current_max_risk:
        current_max_risk = doc_risk

    relevant = set()
    for cat, kw in new_keywords:
        for a in ann:
            if a.get("Question") == kw and a.get("Characteristic") == cat:
                if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                    relevant.add((cat, kw))

    cumulative_by_risk[current_max_risk] += len(relevant)
    seen_keywords.update(current_keywords)

    y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk] + MIN_OFFSET
    color = risk_color[current_max_risk]

    # -----------------------------
    # BUILD PER-DOC HOVER
    # -----------------------------
    hover = f"<b>{doc['name']}</b><br>"
    hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span><br>"
    hover += f"Cumulative Signals: <b>{cumulative_by_risk[current_max_risk]}</b><br>"

    if relevant:
        hover += f"<b>New {risk_label[current_max_risk]} Risk Signals: ({len(relevant)})</b><br>"
        temp = {}
        for cat, kw in relevant:
            temp.setdefault(cat, []).append(kw)

        for cat, kws in temp.items():
            hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"
    else:
        hover += f"<b>No new {risk_label[current_max_risk]} signals</b><br>"

    hover += "<br>"

    grouped[doc["display_date"]].append({
        "hover": hover,
        "y": y_val,
        "color": color
    })

# -----------------------------
# STEP 5: BUILD FINAL PLOT DATA
# -----------------------------
x_vals = []
y_vals = []
colors = []
hover_texts = []

sorted_dates = sorted(grouped.keys())

for i, date in enumerate(sorted_dates):
    entries = grouped[date]

    combined_hover = f"<b>Date: {date.strftime('%Y-%m-%d')}</b><br><br>"
    combined_hover += "".join([e["hover"] for e in entries])

    # take last state (latest doc that day)
    y_val = entries[-1]["y"]
    color = entries[-1]["color"]

    x_vals.append(i)
    y_vals.append(y_val)
    colors.append(color)
    hover_texts.append(combined_hover)

# -----------------------------
# STEP 6: PLOT
# -----------------------------
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x_vals,
    y=y_vals,
    mode='lines+markers',
    marker=dict(size=12, color=colors, line=dict(width=1, color='black')),
    line=dict(width=3),
    text=hover_texts,
    hoverinfo='text'
))

# -----------------------------
# BACKGROUND REGIONS
# -----------------------------
fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=0, y1=low_height,
              fillcolor="green", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height, y1=low_height+mod_height,
              fillcolor="orange", opacity=0.08, layer="below", line_width=0)

fig.add_shape(type="rect", xref="paper", yref="y",
              x0=0, x1=1, y0=low_height+mod_height, y1=total_height,
              fillcolor="red", opacity=0.08, layer="below", line_width=0)

# -----------------------------
# FINAL LAYOUT
# -----------------------------
fig.update_layout(
    title="Claim Risk Progression Timeline",

    xaxis=dict(
        title="Date Document Recieved (Grouped by Date)",
        tickvals=x_vals,
        ticktext=[d.strftime("%b %d") for d in sorted_dates]
    ),

    yaxis=dict(
        title="Claim Risk",
        tickvals=[
            low_height / 2,
            low_height + mod_height / 2,
            low_height + mod_height + high_height / 2
        ],
        ticktext=["Low Risk", "Moderate Risk", "High Risk"],
        range=[0, total_height]
    ),

    template="plotly_white",
    height=700,
    width=1200,

    hoverlabel=dict(
        bgcolor="white",
        font_size=13,
        font_family="Arial",
        font_color="black",
        bordercolor="lightgrey",
        align="left"
    )
)

fig.show()

# %% [markdown]
# ### Empro Claim file - 170949

# %%
https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/15/docs/?annotations=true&limit=5&offset=0
# Out:
#   Cell In[116], line 1
#     https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/15/docs/?annotations=true&limit=5&offset=0
#           ^
# SyntaxError: invalid syntax

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9...._.5Ua-yDPgBDCVhsxdxTfzkY7B96qYTDPugGvO5lyBpqwgKrGuna5MwETfG9_1NGYDfZONlVZIgR78aMs2Bh9_wbPDsZsnxojLSNa8fBl4rWsNmef3sVpxmGgly7V0mhHK5LPLcgvQuSPaQtzJPaSPiPlWZkiXjrHqJFedNyHiwsSvmnjLFDrH-_PqjV5MAGBJ3SKl-xMeAIQKbvhijgWNLXER8KKM4Lsr2QAgrQiy89JOuHHBy_hmbxAzfXDbx0-nwMsTwEhjIFd1SYsy3_ErnMoO3wCuk8Mp_mFi89xikeLuGFzbgE7C4loIX1VWWRFxRv_HaSbWfzpmXVyfIeih2A"
search_api_url = lambda i: f"https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/15/docs/?annotations=true&limit=5&offset={i}"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
final_results_2 = []
next_api = search_api_url(0)
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
count = response_json["count"]
for i in range(0,count,5):
    response = requests.get(
                search_api_url(i),  # Replace with actual API endpoint
                headers=headers,
            )
    if not response:
        break
    response_json = response.json()
    final_results_2.extend(response_json["results"])

# %%
len(final_results_2)
# Out:
# 77

# %%
import pickle

with open("risk-report-timeline-results-170949.pkl", "wb") as f:
    pickle.dump(final_results_2, f)

# %%
def get_plot(final_results):
    # -----------------------------
    # INPUT DATA
    # -----------------------------
    data = final_results

    # -----------------------------
    # CONFIG
    # -----------------------------
    risk_map = {"L": 1, "M": 2, "H": 3}
    risk_label = {1: "Low", 2: "Moderate", 3: "High"}
    risk_color = {1: "green", 2: "orange", 3: "red"}

    MIN_OFFSET = 1
    PADDING = 2

    # -----------------------------
    # STEP 1: ASSIGN DATES
    # -----------------------------
    date_buckets = {
        "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
        "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
        "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
    }

    def random_date(start, end):
        delta = end - start
        return start + timedelta(days=random.randint(0, delta.days))

    def get_date(doc):
        """
        Robust date extractor:
        1. Try extracting date near 'Doc Date'
        2. Else extract ANY date from name
        3. Else fallback to created_at

        Supports formats:
        - 1.30.2024, 6.11.23
        - 12-12-2014, 1-30-2024
        - 12/05/23
        """

        name = doc.get("name", "")

        # -----------------------------
        # HELPER: parse date string
        # -----------------------------
        def parse_date(date_str):
            normalized = re.sub(r"[./]", "-", date_str)

            formats = [
                "%d-%m-%Y",
                "%m-%d-%Y",
                "%d-%m-%y",
                "%m-%d-%y",
                "%Y-%m-%d"
            ]

            for fmt in formats:
                try:
                    dt = datetime.strptime(normalized, fmt)

                    # Fix 2-digit year
                    if dt.year < 100:
                        dt = dt.replace(year=2000 + dt.year)

                    return dt
                except ValueError:
                    continue

            return None

        # -----------------------------
        # STEP 1: Try "Doc Date"
        # -----------------------------
        match = re.search(r"Doc Date(.{0,40})", name, re.IGNORECASE)

        if match:
            chunk = match.group(1)

            date_match = re.search(r"(\d{1,2}[-./]\d{1,2}[-./]\d{2,4})", chunk)

            if date_match:
                dt = parse_date(date_match.group(1))
                if dt:
                    return dt

        # -----------------------------
        # STEP 2: Try ANY date in name
        # -----------------------------
        all_dates = re.findall(r"\d{1,2}[-./]\d{1,2}[-./]\d{2,4}", name)

        for d in all_dates:
            dt = parse_date(d)
            if dt:
                return dt

        # -----------------------------
        # STEP 3: Fallback → created_at
        # -----------------------------
        created_at = doc.get("created_at")

        if created_at:
            try:
                dt = datetime.fromisoformat(created_at)

                if dt.tzinfo is not None:
                    dt = dt.replace(tzinfo=None)

                return dt
            except Exception:
                pass

        # अंतिम fallback
        return datetime.now()
        
    for doc in data:
        # risk = doc["risk_info"]["document_risk_score"]
        # start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
        doc["display_date"] = get_date(doc)

    docs = sorted(data, key=lambda x: x["display_date"])
    # docs[-1]["display_date"] = docs[-2]["display_date"]
    # -----------------------------
    # STEP 2: FIRST PASS (same)
    # -----------------------------
    seen_keywords = set()
    current_max_risk = 0

    cumulative_by_risk = {1: 0, 2: 0, 3: 0}
    max_by_risk = {1: 0, 2: 0, 3: 0}

    for doc in docs:
        doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
        ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

        current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
        new_keywords = current_keywords - seen_keywords

        if doc_risk > current_max_risk:
            current_max_risk = doc_risk

        relevant = set()
        for cat, kw in new_keywords:
            for a in ann:
                if a.get("Question") == kw and a.get("Characteristic") == cat:
                    if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                        relevant.add((cat, kw))

        cumulative_by_risk[current_max_risk] += len(relevant)
        max_by_risk[current_max_risk] = max(
            max_by_risk[current_max_risk],
            cumulative_by_risk[current_max_risk]
        )

        seen_keywords.update(current_keywords)

    # -----------------------------
    # STEP 3: REGION HEIGHTS
    # -----------------------------
    low_height = max_by_risk[1] + PADDING + MIN_OFFSET
    mod_height = max_by_risk[2] + PADDING + MIN_OFFSET
    high_height = max_by_risk[3] + PADDING + MIN_OFFSET

    risk_base = {
        1: 0,
        2: low_height,
        3: low_height + mod_height
    }

    total_height = low_height + mod_height + high_height

    # -----------------------------
    # STEP 4: SECOND PASS + GROUPING
    # -----------------------------
    seen_keywords = set()
    current_max_risk = 0
    cumulative_by_risk = {1: 0, 2: 0, 3: 0}
    cumulative_keywords_by_risk = {1: set(), 2: set(), 3: set()}

    grouped = defaultdict(list)

    prev_date = None
    for doc in docs:
        doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
        ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

        current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
        new_keywords = current_keywords - seen_keywords

        if doc_risk > current_max_risk:
            current_max_risk = doc_risk

        relevant = set()
        for cat, kw in new_keywords:
            for a in ann:
                if a.get("Question") == kw and a.get("Characteristic") == cat:
                    if risk_map.get(a.get("RiskCategory"), 0) == current_max_risk:
                        relevant.add((cat, kw))

        cumulative_by_risk[current_max_risk] += len(relevant)
        
        seen_keywords.update(current_keywords)

        y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk] + MIN_OFFSET
        color = risk_color[current_max_risk]

        # -----------------------------
        # BUILD PER-DOC HOVER
        # -----------------------------
        doc_id = doc.get("id")

        doc_url = f"https://claimlens.empro.doclens.ai/claim-file/15/?dep=3&folder=5&defaultDoc={doc_id}"

        hover = (
            f"<a href='{doc_url}' target='_blank' "
            f"style='text-decoration:underline;'>"
            f"<b>Document {doc_id}</b></a><br>"
        )
        hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span>"
        # hover += f"Cumulative Signals Count: <b>{cumulative_by_risk[current_max_risk]}</b><br>"

        # NEW: cumulative keyword list
        # if cumulative_keywords_by_risk[current_max_risk]:
        #     hover += "<b>All Signals So Far:</b><br>"

        #     temp_all = {}
        #     for cat, kw in cumulative_keywords_by_risk[current_max_risk]:
        #         temp_all.setdefault(cat, []).append(kw)

        #     for cat, kws in temp_all.items():
        #         hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"

        hover += "<br>"

        # existing new signals
        if relevant:
            hover += f"<b>New {risk_label[current_max_risk]} Risk Signals: ({len(relevant)})</b><br>"
            temp = {}
            for cat, kw in relevant:
                temp.setdefault(cat, []).append(kw)

            for cat, kws in temp.items():
                hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"
        else:
            hover += f"<b>No new {risk_label[current_max_risk]} signals</b><br>"

        hover += "<br>"

        grouped[doc["display_date"]].append({
            "hover": hover,
            "y": y_val,
            "color": color,
            "risk_level": current_max_risk,
            "cumulative_snapshot": {
                1: cumulative_keywords_by_risk[1].copy(),
                2: cumulative_keywords_by_risk[2].copy(),
                3: cumulative_keywords_by_risk[3].copy()
            }
        })
        cumulative_keywords_by_risk[current_max_risk].update(relevant)

    # -----------------------------
    # STEP 5: BUILD FINAL PLOT DATA
    # -----------------------------
    x_vals = []
    y_vals = []
    colors = []
    hover_texts = []

    sorted_dates = sorted(grouped.keys())
    doc_ids_per_point = []

    for i, date in enumerate(sorted_dates):
        ids = [doc.get("id") for doc in data if doc["display_date"] == date]
        doc_ids_per_point.append(ids)

        entries = grouped[date]

        # Take LAST entry of that date (latest state)
        last_entry = entries[-1]

        risk_level = last_entry["risk_level"]
        color = last_entry["color"]
        y_val = last_entry["y"]

        cumulative_snapshot = last_entry["cumulative_snapshot"]

        # -----------------------------
        # BUILD FINAL HOVER
        # -----------------------------
        combined_hover = f"<b>Date: {date.strftime('%Y-%m-%d')}</b><br><br>"

        # ✅ CUMULATIVE (correct snapshot now)
        if cumulative_snapshot[risk_level]:
            combined_hover += f"<b>Cumulative {risk_label[risk_level]} Signals So Far: ({len(cumulative_snapshot[risk_level])})</b><br>"

            temp_all = {}
            for cat, kw in cumulative_snapshot[risk_level]:
                temp_all.setdefault(cat, []).append(kw)

            for cat, kws in temp_all.items():
                combined_hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"

            combined_hover += "<br>"

        # ✅ PER-DOC DETAILS (THIS WAS MISSING EFFECTIVELY)
        for e in entries:
            combined_hover += e["hover"]

        x_vals.append(i)
        y_vals.append(y_val)
        colors.append(color)
        hover_texts.append(combined_hover)
    # -----------------------------
    # STEP 6: PLOT
    # -----------------------------
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=x_vals,
        y=y_vals,
        mode='markers+lines',
        marker=dict(
            size=14,
            color=colors,
            line=dict(width=2, color='black')
        ),
        line=dict(width=2),
        text=hover_texts,
        hovertemplate="%{text}<extra></extra>",
        customdata=[doc_ids_per_point]  # we’ll define this
    ))

    def open_doc(trace, points, state):
        if points.point_inds:
            idx = points.point_inds[0]
            doc_ids = trace.customdata[idx]

            # open first doc (or modify logic)
            doc_id = doc_ids[-1]

            url = f"https://claimlens.empro.doclens.ai/claim-file/15/?dep=3&folder=5&defaultDoc={doc_id}"
            import webbrowser
            webbrowser.open_new_tab(url)

    fig.data[0].on_click(open_doc)

    # -----------------------------
    # BACKGROUND REGIONS
    # -----------------------------
    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=0, y1=low_height,
                fillcolor="green", opacity=0.08, layer="below", line_width=0)

    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=low_height, y1=low_height+mod_height,
                fillcolor="orange", opacity=0.08, layer="below", line_width=0)

    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=low_height+mod_height, y1=total_height,
                fillcolor="red", opacity=0.08, layer="below", line_width=0)

    # -----------------------------
    # FINAL LAYOUT
    # -----------------------------
    fig.update_layout(
        title="Claim Risk Progression Timeline",

        xaxis=dict(
            title="Date Document Recieved (Grouped by Date)",
            tickvals=x_vals,
            ticktext=[d.strftime("%b %d, %Y") for d in sorted_dates]
        ),

        yaxis=dict(
            title="Claim Risk",
            tickvals=[
                low_height / 2,
                low_height + mod_height / 2,
                low_height + mod_height + high_height / 2
            ],
            ticktext=["Low Risk", "Moderate Risk", "High Risk"],
            range=[0, total_height]
        ),

        template="plotly_white",
        height=700,
        width=1200,
        hovermode="closest",
        margin=dict(t=80, b=80),
        hoverlabel=dict(
            bgcolor="white",
            font_size=13,
            font_family="Arial",
            font_color="black",
            bordercolor="lightgrey",
            align="left"
        )
    )

    fig.show()

# %%
get_plot(final_results_2)

# %%
import pickle

with open("risk-report-timeline-results-170949.pkl", "wb") as f:
    pickle.dump(final_results_2, f)

# %% [markdown]
# ### Empro Claim File 170948

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9...._.5Ua-yDPgBDCVhsxdxTfzkY7B96qYTDPugGvO5lyBpqwgKrGuna5MwETfG9_1NGYDfZONlVZIgR78aMs2Bh9_wbPDsZsnxojLSNa8fBl4rWsNmef3sVpxmGgly7V0mhHK5LPLcgvQuSPaQtzJPaSPiPlWZkiXjrHqJFedNyHiwsSvmnjLFDrH-_PqjV5MAGBJ3SKl-xMeAIQKbvhijgWNLXER8KKM4Lsr2QAgrQiy89JOuHHBy_hmbxAzfXDbx0-nwMsTwEhjIFd1SYsy3_ErnMoO3wCuk8Mp_mFi89xikeLuGFzbgE7C4loIX1VWWRFxRv_HaSbWfzpmXVyfIeih2A"
search_api_url = lambda i: f"https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/24/docs/?annotations=true&limit=5&offset={i}"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
final_results_3 = []
next_api = search_api_url(0)
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
count = response_json["count"]
for i in range(0,count,5):
    response = requests.get(
                search_api_url(i),  # Replace with actual API endpoint
                headers=headers,
            )
    if not response:
        break
    response_json = response.json()
    final_results_3.extend(response_json["results"])

# %%
len(final_results_3)
# Out:
# 128

# %%
import pickle

with open("risk-report-timeline-results-170948.pkl", "wb") as f:
    pickle.dump(final_results_3, f)

# %% [markdown]
# ### Empro Claim File 144415

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9.....I-PtikIwltc-vPkUMKeWlUjLCYgRu3-Nsa2Kya0NvjamMxO3q3TfyMyJ6cFbrUyA5M-mV2OOghzVtX7CsnA-OtSRSCLDDuGxJo3-R-2JtN_s7rUM0XHdl7TfmpiP4gyZg0MckYUVzKf_dc5WOKs2rOIcJIrGqBkPgWuy6B7j1t5ceX095lpS7WyXWg3YdavfOaCoOGpz5rmLvI9hikFqLw82d5dxPMGf4WGne88kPRZOl9tHY55Ra13Yb5m6mMCAgT86spaJvhVeMSsAsctb3ijgO-MhcEGfh8I1xR8eOJV17UCTmWEjebE3nVEU4almD4ZSNvLz2BmSEt4fl9F4Lg"
search_api_url = lambda i: f"https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/13/docs/?annotations=true&limit=5&offset={i}"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
final_results_4 = []
next_api = search_api_url(0)
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
count = response_json["count"]
for i in range(0,count,5):
    response = requests.get(
                search_api_url(i),  # Replace with actual API endpoint
                headers=headers,
            )
    if not response:
        break
    response_json = response.json()
    final_results_4.extend(response_json["results"])

# %%
len(final_results_4)
# Out:
# 137

# %%
import pickle

with open("risk-report-timeline-results-144415.pkl", "wb") as f:
    pickle.dump(final_results_4, f)

# %% [markdown]
# ### Empro Claim File 157134

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9.....I-PtikIwltc-vPkUMKeWlUjLCYgRu3-Nsa2Kya0NvjamMxO3q3TfyMyJ6cFbrUyA5M-mV2OOghzVtX7CsnA-OtSRSCLDDuGxJo3-R-2JtN_s7rUM0XHdl7TfmpiP4gyZg0MckYUVzKf_dc5WOKs2rOIcJIrGqBkPgWuy6B7j1t5ceX095lpS7WyXWg3YdavfOaCoOGpz5rmLvI9hikFqLw82d5dxPMGf4WGne88kPRZOl9tHY55Ra13Yb5m6mMCAgT86spaJvhVeMSsAsctb3ijgO-MhcEGfh8I1xR8eOJV17UCTmWEjebE3nVEU4almD4ZSNvLz2BmSEt4fl9F4Lg"
search_api_url = lambda i: f"https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/20/docs/?annotations=true&limit=5&offset={i}"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
final_results_5 = []
next_api = search_api_url(0)
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
count = response_json["count"]
for i in range(0,count,5):
    response = requests.get(
                search_api_url(i),  # Replace with actual API endpoint
                headers=headers,
            )
    if not response:
        break
    response_json = response.json()
    final_results_5.extend(response_json["results"])

# %%
len(final_results_5)
# Out:
# 145

# %%
import pickle

with open("risk-report-timeline-results-157314.pkl", "wb") as f:
    pickle.dump(final_results_5, f)

# %%
import requests

id_token = "eyJraWQiOiJKSUFXTDEyQmVCTlFtTWVESFZcLzV4cU5PS0h1ck5RRHVlYzBrM2lETURrZz0iLCJhbGciOiJSUzI1NiJ9.....I-PtikIwltc-vPkUMKeWlUjLCYgRu3-Nsa2Kya0NvjamMxO3q3TfyMyJ6cFbrUyA5M-mV2OOghzVtX7CsnA-OtSRSCLDDuGxJo3-R-2JtN_s7rUM0XHdl7TfmpiP4gyZg0MckYUVzKf_dc5WOKs2rOIcJIrGqBkPgWuy6B7j1t5ceX095lpS7WyXWg3YdavfOaCoOGpz5rmLvI9hikFqLw82d5dxPMGf4WGne88kPRZOl9tHY55Ra13Yb5m6mMCAgT86spaJvhVeMSsAsctb3ijgO-MhcEGfh8I1xR8eOJV17UCTmWEjebE3nVEU4almD4ZSNvLz2BmSEt4fl9F4Lg"
search_api_url = "https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/20/get_entities/?entity_type=Attorney"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
attorney_results = []
next_api = search_api_url
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
attorney_results = response_json

# %%
attorney_results
# Out:
# {'1947': [{'id': 460,
#    'entity_type': 'attorney',
#    'attorney_name': 'gary nielsen',
#    'rating': 'L',
#    'law_firm_name': 'Pegalis & Erickson, L.L.C.',
#    'law_firm_address': '1 Hollow Lane, Suite 107 Lake Success, New York 11042',
#    'chunks': [{'layout_ids': 'L1-77e40c35',
#      'document_id': 1947,
#      'page_number': '1',
#      'claimfile_id': 20,
#      'page_content': "The fourth and final day of the plaintiff's deposition was held on July 15, 2016. She was again represented by her counsel, Gary M. Nielsen, Esq. of Pegalis & Erickson, LLC. Nyack Hospital was represented by David Javer, Esq. of Schiavetti, Corgan, DiEdwards, Weinberg & Nicholson, LLP. Jonathan Weinstein, Esq. of Voute, Lohrfink, Magro & McAndrew, LLP represented Mark Papish, M.D.; Rachel Appel, RPA; and Emergency Medical Association of New York, P.C. Ginette Portera, Esq",
# ...

# %%
search_api_url = "https://aizooq5vdd.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/claim_file/20/get_entities/?entity_type=Court"
# Prepare headers with id token
headers = {
    'Authorization': f'{id_token}',
    'Content-Type': 'application/json'
}
court_results = []
next_api = search_api_url
# strings_api_url = "https://kq0zwv7nqa.execute-api.us-east-2.amazonaws.com/prod/api/v1/documents/recommended-search-strings/"

# response = requests.get(
#             next_api,  # Replace with actual API endpoint
#             headers=headers,
#         )
# response_json = response.json()
# print(response_json)
response = requests.get(
            next_api,  # Replace with actual API endpoint
            headers=headers,
        )
response_json = response.json()
court_results = response_json

# %%
court_results
# Out:
# {'1938': [{'id': 431,
#    'entity_type': 'court',
#    'court_name': 'Supreme court of the state of new york county of westchester',
#    'rating': 'M',
#    'chunks': [{'layout_ids': 'L1-a74107a3,L1-bed99f10,L1-ed504098,L1-943f303b,L1-2631c711',
#      'document_id': 1938,
#      'page_number': '1',
#      'claimfile_id': 20,
#      'page_content': "VIA E-MAIL\nPhysicians' Reciprocal Insurers 1200C Scottsville Road, Suite 195 Rochester, NY 14624 Attn: Julia White\nRE: Olavarria/Pellerin V. SLCH, et al. Our File No.: 7560 File No.: 157134\nDear Julia:\nOn November 14, 2016, I appeared for a further compliance conference before Court Attorney-Referee, Dorian Wood, at the Supreme Court, Westchester County in White Plains, New York.",
#      'document_name': 'CLM - Defense Counsel General Correspondence DISCOVERY STATUS UPDATE Clm    157134 - OLAVARRIA, SARA vs. MONTEFIORE ST. LUKE S CORNWALL - Doc Date 11-....pdf',
#      'claimfile_name': '157134'}]}],
#  '1951': [{'id': 429,
# ...

# %% [markdown]
# ### Plotting

# %%
import plotly.graph_objects as go
from collections import defaultdict
from datetime import datetime
import re
import pickle

risk_map = {"L": 1, "M": 2, "H": 3}
risk_label = {1: "Low", 2: "Moderate", 3: "High"}
risk_color = {1: "green", 2: "orange", 3: "red"}

# -----------------------------
# DATE PARSER
# -----------------------------
def get_date(doc):
    name = doc.get("name", "")

    def parse_date(date_str):
        normalized = re.sub(r"[./]", "-", date_str)
        formats = ["%d-%m-%Y", "%m-%d-%Y", "%d-%m-%y", "%m-%d-%y"]

        for fmt in formats:
            try:
                dt = datetime.strptime(normalized, fmt)
                if dt.year < 100:
                    dt = dt.replace(year=2000 + dt.year)
                return dt
            except:
                continue
        return None

    match = re.search(r"Doc Date(.{0,40})", name, re.IGNORECASE)
    if match:
        chunk = match.group(1)
        m = re.search(r"(\d{1,2}[-./]\d{1,2}[-./]\d{2,4})", chunk)
        if m:
            dt = parse_date(m.group(1))
            if dt:
                return dt

    all_dates = re.findall(r"\d{1,2}[-./]\d{1,2}[-./]\d{2,4}", name)
    for d in all_dates:
        dt = parse_date(d)
        if dt:
            return dt

    return datetime.fromisoformat(doc["created_at"]).replace(tzinfo=None)

def build_entity_map(attorney_results, court_results):
    """
    Returns:
    {
        doc_id: [(category, keyword, risk), ...]
    }
    """

    entity_map = defaultdict(list)

    # -----------------------------
    # ATTORNEY
    # -----------------------------
    for doc_id, entities in attorney_results.items():
        for e in entities:
            name = e.get("attorney_name", "Unknown Attorney")
            rating = e.get("rating", "L")
            entity_map[int(doc_id)].append(("Attorney", name, rating))

    # -----------------------------
    # COURT
    # -----------------------------
    for doc_id, entities in court_results.items():
        for e in entities:
            name = e.get("court_name", "Unknown Court")
            rating = e.get("rating", "L")
            entity_map[int(doc_id)].append(("Court", name, rating))

    return entity_map

# -----------------------------
# MAIN FUNCTION
# -----------------------------
def get_plot(final_results, filter_start_date, attorney_results, court_results):
    # -----------------------------
    # INPUT DATA
    # -----------------------------
    data = final_results
    entity_map = build_entity_map(attorney_results, court_results)

    # -----------------------------
    # CONFIG
    # -----------------------------
    risk_map = {"L": 1, "M": 2, "H": 3}
    risk_label = {1: "Low", 2: "Moderate", 3: "High"}
    risk_color = {1: "green", 2: "orange", 3: "red"}

    MIN_OFFSET = 1
    PADDING = 2

    # -----------------------------
    # STEP 1: ASSIGN DATES
    # -----------------------------
    date_buckets = {
        "L": (datetime(2026, 1, 1), datetime(2026, 1, 31)),
        "M": (datetime(2026, 2, 1), datetime(2026, 2, 28)),
        "H": (datetime(2026, 3, 1), datetime(2026, 3, 31)),
    }

    def random_date(start, end):
        delta = end - start
        return start + timedelta(days=random.randint(0, delta.days))

    def get_date(doc):
        """
        Robust date extractor:
        1. Try extracting date near 'Doc Date'
        2. Else extract ANY date from name
        3. Else fallback to created_at

        Supports formats:
        - 1.30.2024, 6.11.23
        - 12-12-2014, 1-30-2024
        - 12/05/23
        """

        name = doc.get("name", "")

        # -----------------------------
        # HELPER: parse date string
        # -----------------------------
        def parse_date(date_str):
            normalized = re.sub(r"[./]", "-", date_str)

            formats = [
                "%d-%m-%Y",
                "%m-%d-%Y",
                "%d-%m-%y",
                "%m-%d-%y",
                "%Y-%m-%d"
            ]

            for fmt in formats:
                try:
                    dt = datetime.strptime(normalized, fmt)

                    # Fix 2-digit year
                    if dt.year < 100:
                        dt = dt.replace(year=2000 + dt.year)

                    return dt
                except ValueError:
                    continue

            return None

        # -----------------------------
        # STEP 1: Try "Doc Date"
        # -----------------------------
        match = re.search(r"Doc Date(.{0,40})", name, re.IGNORECASE)

        if match:
            chunk = match.group(1)

            date_match = re.search(r"(\d{1,2}[-./]\d{1,2}[-./]\d{2,4})", chunk)

            if date_match:
                dt = parse_date(date_match.group(1))
                if dt:
                    return dt

        # -----------------------------
        # STEP 2: Try ANY date in name
        # -----------------------------
        all_dates = re.findall(r"\d{1,2}[-./]\d{1,2}[-./]\d{2,4}", name)

        for d in all_dates:
            dt = parse_date(d)
            if dt:
                return dt

        # -----------------------------
        # STEP 3: Fallback → created_at
        # -----------------------------
        created_at = doc.get("created_at")

        if created_at:
            try:
                dt = datetime.fromisoformat(created_at)

                if dt.tzinfo is not None:
                    dt = dt.replace(tzinfo=None)

                return dt
            except Exception:
                pass

        # अंतिम fallback
        return datetime.now()
        
    for doc in data:
        # risk = doc["risk_info"]["document_risk_score"]
        # start, end = date_buckets.get(risk, (datetime(2026,1,1), datetime(2026,3,31)))
        doc["display_date"] = get_date(doc)
    data = [doc for doc in data if doc["display_date"] <= filter_start_date]
    docs = sorted(data, key=lambda x: x["display_date"])
    # docs[-1]["display_date"] = docs[-2]["display_date"]
    # -----------------------------
    # STEP 2: FIRST PASS (same)
    # -----------------------------
    seen_keywords = set()
    current_max_risk = 0

    cumulative_by_risk = {1: 0, 2: 0, 3: 0}
    max_by_risk = {1: 0, 2: 0, 3: 0}

    for doc in docs:
        doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
        ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

        doc_id = doc.get("id")

        # Existing keyword signals
        current_keywords = {
            (a.get("Characteristic"), a.get("Question"), a.get("RiskCategory"))
            for a in ann
        }

        # Add entity signals
        entity_signals = entity_map.get(doc_id, [])

        for cat, name, rating in entity_signals:
            current_keywords.add((cat, name, rating))
        new_keywords = current_keywords - seen_keywords

        if doc_risk > current_max_risk:
            current_max_risk = doc_risk

        relevant = set()
        for cat, name, rating in new_keywords:
            if risk_map.get(rating, 0) == current_max_risk:
                relevant.add((cat, name))

        cumulative_by_risk[current_max_risk] += len(relevant)
        max_by_risk[current_max_risk] = max(
            max_by_risk[current_max_risk],
            cumulative_by_risk[current_max_risk]
        )

        seen_keywords.update(current_keywords)

    # -----------------------------
    # STEP 3: REGION HEIGHTS
    # -----------------------------
    low_height = max_by_risk[1] + PADDING + MIN_OFFSET
    mod_height = max_by_risk[2] + PADDING + MIN_OFFSET
    high_height = max_by_risk[3] + PADDING + MIN_OFFSET

    risk_base = {
        1: 0,
        2: low_height,
        3: low_height + mod_height
    }

    total_height = low_height + mod_height + high_height

    # -----------------------------
    # STEP 4: SECOND PASS + GROUPING
    # -----------------------------
    seen_keywords = set()
    current_max_risk = 0
    cumulative_by_risk = {1: 0, 2: 0, 3: 0}
    cumulative_keywords_by_risk = {1: set(), 2: set(), 3: set()}

    grouped = defaultdict(list)

    prev_date = None
    for doc in docs:
        doc_risk = risk_map.get(doc["risk_info"]["document_risk_score"], 0)
        ann = doc.get("annotations", {}).get("claim-characteristics", {}).get("annotations", [])

        current_keywords = {(a.get("Characteristic"), a.get("Question")) for a in ann}
        # Add entity signals
        entity_signals = entity_map.get(doc_id, [])

        for cat, name, rating in entity_signals:
            current_keywords.add((cat, name, rating))
        new_keywords = current_keywords - seen_keywords

        if doc_risk > current_max_risk:
            current_max_risk = doc_risk

        relevant = set()
        for cat, name, rating in new_keywords:
            if risk_map.get(rating, 0) == current_max_risk:
                relevant.add((cat, name))

        cumulative_by_risk[current_max_risk] += len(relevant)
        
        seen_keywords.update(current_keywords)

        y_val = risk_base[current_max_risk] + cumulative_by_risk[current_max_risk] + MIN_OFFSET
        color = risk_color[current_max_risk]

        # -----------------------------
        # BUILD PER-DOC HOVER
        # -----------------------------
        doc_id = doc.get("id")

        doc_url = f"https://claimlens.empro.doclens.ai/claim-file/15/?dep=3&folder=5&defaultDoc={doc_id}"

        hover = (
            f"<a href='{doc_url}' target='_blank' "
            f"style='text-decoration:underline;'>"
            f"<b>Document {doc_id}</b></a><br>"
        )
        hover += f"Claim Risk: <span style='color:{color}'><b>{risk_label[current_max_risk]}</b></span>"
        # hover += f"Cumulative Signals Count: <b>{cumulative_by_risk[current_max_risk]}</b><br>"

        # NEW: cumulative keyword list
        # if cumulative_keywords_by_risk[current_max_risk]:
        #     hover += "<b>All Signals So Far:</b><br>"

        #     temp_all = {}
        #     for cat, kw in cumulative_keywords_by_risk[current_max_risk]:
        #         temp_all.setdefault(cat, []).append(kw)

        #     for cat, kws in temp_all.items():
        #         hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"

        hover += "<br>"

        # existing new signals
        if relevant:
            hover += f"<b>New {risk_label[current_max_risk]} Risk Signals: ({len(relevant)})</b><br>"
            temp = {}
            for cat, kw in relevant:
                temp.setdefault(cat, []).append(kw)

            for cat, kws in temp.items():
                hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"
        else:
            hover += f"<b>No new {risk_label[current_max_risk]} signals</b><br>"

        hover += "<br>"

        grouped[doc["display_date"]].append({
            "hover": hover,
            "y": y_val,
            "color": color,
            "risk_level": current_max_risk,
            "cumulative_snapshot": {
                1: cumulative_keywords_by_risk[1].copy(),
                2: cumulative_keywords_by_risk[2].copy(),
                3: cumulative_keywords_by_risk[3].copy()
            }
        })
        cumulative_keywords_by_risk[current_max_risk].update(relevant)

    # -----------------------------
    # STEP 5: BUILD FINAL PLOT DATA
    # -----------------------------
    x_vals = []
    y_vals = []
    colors = []
    hover_texts = []

    sorted_dates = sorted(grouped.keys())
    doc_ids_per_point = []

    for i, date in enumerate(sorted_dates):
        ids = [doc.get("id") for doc in data if doc["display_date"] == date]
        doc_ids_per_point.append(ids)

        entries = grouped[date]

        # Take LAST entry of that date (latest state)
        last_entry = entries[-1]

        risk_level = last_entry["risk_level"]
        color = last_entry["color"]
        y_val = last_entry["y"]

        cumulative_snapshot = last_entry["cumulative_snapshot"]

        # -----------------------------
        # BUILD FINAL HOVER
        # -----------------------------
        combined_hover = f"<b>Date: {date.strftime('%Y-%m-%d')}</b><br><br>"

        # ✅ CUMULATIVE (correct snapshot now)
        if cumulative_snapshot[risk_level]:
            combined_hover += f"<b>Cumulative {risk_label[risk_level]} Signals So Far: ({len(cumulative_snapshot[risk_level])})</b><br>"

            temp_all = {}
            for cat, kw in cumulative_snapshot[risk_level]:
                temp_all.setdefault(cat, []).append(kw)

            for cat, kws in temp_all.items():
                combined_hover += f"<b>{cat}</b>: <span style='color:{color}'>{', '.join(set(kws))}</span><br>"

            combined_hover += "<br>"

        # ✅ PER-DOC DETAILS (THIS WAS MISSING EFFECTIVELY)
        for e in entries:
            combined_hover += e["hover"]

        x_vals.append(i)
        y_vals.append(y_val)
        colors.append(color)
        hover_texts.append(combined_hover)
    # -----------------------------
    # STEP 6: PLOT
    # -----------------------------
    fig = go.Figure()

    fig.add_trace(go.Scatter(
        x=x_vals,
        y=y_vals,
        mode='markers+lines',
        marker=dict(
            size=14,
            color=colors,
            line=dict(width=2, color='black')
        ),
        line=dict(width=2),
        text=hover_texts,
        hovertemplate="%{text}<extra></extra>",
        customdata=[doc_ids_per_point]  # we’ll define this
    ))

    def open_doc(trace, points, state):
        if points.point_inds:
            idx = points.point_inds[0]
            doc_ids = trace.customdata[idx]

            # open first doc (or modify logic)
            doc_id = doc_ids[-1]

            url = f"https://claimlens.empro.doclens.ai/claim-file/15/?dep=3&folder=5&defaultDoc={doc_id}"
            import webbrowser
            webbrowser.open_new_tab(url)

    fig.data[0].on_click(open_doc)

    # -----------------------------
    # BACKGROUND REGIONS
    # -----------------------------
    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=0, y1=low_height,
                fillcolor="green", opacity=0.08, layer="below", line_width=0)

    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=low_height, y1=low_height+mod_height,
                fillcolor="orange", opacity=0.08, layer="below", line_width=0)

    fig.add_shape(type="rect", xref="paper", yref="y",
                x0=0, x1=1, y0=low_height+mod_height, y1=total_height,
                fillcolor="red", opacity=0.08, layer="below", line_width=0)

    # -----------------------------
    # FINAL LAYOUT
    # -----------------------------
    fig.update_layout(
        title="Claim Risk Progression Timeline",

        xaxis=dict(
            title="Date Document Received (Grouped by Date)",
            tickvals=x_vals,
            ticktext=[d.strftime("%b %d, %Y") for d in sorted_dates],
            tickfont=dict(size=14)
        ),

        yaxis=dict(
            title="Claim Risk",
            tickvals=[
                low_height / 2,
                low_height + mod_height / 2,
                low_height + mod_height + high_height / 2
            ],
            ticktext=["Low Risk", "Moderate Risk", "High Risk"],
            tickfont=dict(size=14)
        ),

        template="plotly_white",
        height=700,
        width=1200,
        hovermode="closest",
        margin=dict(t=80, b=80),
        hoverlabel=dict(
            bgcolor="white",
            font_size=13,
            font_family="Arial",
            font_color="black",
            bordercolor="lightgrey",
            align="left"
        )
    )

    # fig.show()
    return fig, grouped, sorted_dates

# %%
filter_start_date = datetime(2026, 3, 1)
fig, grouped, date_keys = get_plot(final_results_5, filter_start_date, attorney_results, court_results)

fig.show()
